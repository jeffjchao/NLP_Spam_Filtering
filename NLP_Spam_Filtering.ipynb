# %%
#import necessary packages
import os
import sys
import random
import nltk
from nltk.corpus import stopwords
import time
import numpy as np
from sklearn.model_selection import KFold
import collections
from nltk.metrics.scores import (precision, recall)

# %%
# function to read spam and ham files, train and test a classifier 
def processspamham(limitStr):
      # convert the limit argument from a string to an int
    limit = int(limitStr)

      # start lists for spam and ham email texts
    hamtexts = []
    spamtexts = []
    #os.chdir(dirPath)
      # process all files in directory that end in .txt up to the limit
      #    assuming that the emails are sufficiently randomized
    for file in os.listdir("./corpus/spam"):
        if (file.endswith(".txt")) and (len(spamtexts) < limit):
          # open file for reading and read entire file into a string
            f = open("./corpus/spam/"+file, 'r', encoding="latin-1")
            spamtexts.append (f.read())
            f.close()
    for file in os.listdir("./corpus/ham"):
        if (file.endswith(".txt")) and (len(hamtexts) < limit):
          # open file for reading and read entire file into a string
            f = open("./corpus/ham/"+file, 'r', encoding="latin-1")
            hamtexts.append (f.read())
            f.close()

      # print number emails read
    print ("Number of spam files:",len(spamtexts))
    print ("Number of ham files:",len(hamtexts))
    print

      # create list of mixed spam and ham email documents as (list of words, label)
    global emaildocs
    emaildocs = []
      # add all the spam
    for spam in spamtexts:
        tokens = nltk.word_tokenize(spam)
        emaildocs.append((tokens, 'spam'))
      # add all the regular emails
    for ham in hamtexts:
        tokens = nltk.word_tokenize(ham)
        emaildocs.append((tokens, 'ham'))

      # randomize the list
    random.shuffle(emaildocs)

      # print a few token lists
    for email in emaildocs[:4]:
        print (email)
        print
        
      # possibly filter tokens

      # continue as usual to get all words and create word features

      # feature sets from a feature definition function

      # train classifier and show performance in cross-validation

# %%
processspamham(1000)
# Out:
# Number of spam files: 1000
# Number of ham files: 1000
# (['Subject', ':', 'sitara', '#', '92886', 'for', 'febo', '0', ',', 'any', 'gas', 'taken', 'by', 'global', 'octanes', 'will', 'be', 'priced', 'off', 'of', 'gas', 'daily', 'rather', 'than', 'if', '.', '.', '.', '.', 'i', "'", 've', 'changed', 'the', 'sitara', 'ticket', '.', '.', '.', '.', 'but', 'one', 'of', 'you', 'gentlemen', 'needs', 'to', 'take', 'care', 'of', 'risk', 'assignment', 'impact', '.', '.', '.', '.', 'lee'], 'ham')
# (['Subject', ':', 'entex', 'increase', 'rom', ':', 'huntsville', '/', 'woodlands', '/', 'conroe', '11500', 'by', '8', 'days', '=', '92', ',', '000', 'big', 'ticket', '50000', 'by', '8', 'days', '=', '400', ',', '000', 'ami'], 'ham')
# (['Subject', ':', 'discreet', 'cheapest', 'pr', '!', 'escription', 'd', '\\', 'rugs', 'online', '!'], 'spam')
# (['Subject', ':', 're', ':', '3', '-', 'rivers', '/', 'king', 'ranch', '/', 'hplr', 'liquids', 'i', 'have', 'identified', 'the', 'additional', 'hplc', 'wellhead', 'purchases', 'and', 'have', 'made', 'corrections', 'to', 'the', 'interconnect', 'tickets', 'accordingly', '.', 'jackie', 'is', 'still', 'having', 'difficulty', 'identifying', 'all', 'the', 'wellhead', 'purchase', '.', 'we', 'feel', 'there', 'are', 'at', 'least', '6', 'meters', 'flowing', 'a', 'total', 'of', 'appox', '.', '7000', 'a', 'day', 'that', 'are', 'not', 'showing', 'up', 'on', 'a', 'hplc', 'purchase', 'or', 'a', 'hplr', 'transport', '.', 'i', 'believe', 'she', 'has', 'given', 'you', 'this', 'information', 'and', 'will', 'await', 'instructions', 'or', 'for', 'the', 'purchases', 'to', 'be', 'input', 'reflecting', 'the', 'proper', 'enron', 'entity', 'purchasing', 'these', 'volumes', '.', 'we', 'have', 'worked', 'very', 'hard', 'on', 'this', 'issue', 'and', 'i', 'apologize', 'that', 'it', 'has', 'not', 'yet', 'been', 'entirely', 'corrected', '.'], 'ham')

# %%
#defining set of words that will be used for features
#we'll find the 2000 most common words and used them as an important feature of the whole corpus

all_words = [word for (email,category) in emaildocs for word in email]
top_words = nltk.FreqDist(all_words)
most_common_words = top_words.most_common(2000)
word_features = [word for (word,count) in most_common_words]

#checking if we have the 2000 words we need
len(set(all_words))
# Out:
# 37261

# %%
word_features[:20]
# Out:
# ['-',
#  '.',
#  '/',
#  ',',
#  ':',
#  'the',
#  'to',
#  'ect',
#  'and',
#  '@',
#  'of',
#  'a',
#  'for',
#  'you',
#  'in',
#  'is',
#  'this',
#  'hou',
#  'on',
#  '=']

# %%
#now we will use that list of most frequent words in the entire corpus
#to iterate over each sentence and check if any of those words are present
#in that way, we will see if this unigram corpus feature is present on that particular sentence
#using Boolean logic that matches values and returns 'True' or 'False'
#we do this by defining a Python "function," i.e.a piece of code writen to be reused
def document_features(document, word_features):
    document_words = set(document)
    #we open a Python dictionary instead of a list
    features = {}
    for word in word_features:
        #checking if the word from word_features matches a word in the document
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
#now we apply the function to the document dataset
featuresets = [(document_features(d, word_features), c) for (d, c) in emaildocs]

#we print the list of features matches for the first document ([0]) in the corpus
#we'll see a Python dictionary with the key being the feature word
#and the value being 'True' or 'False' according to that word being matched in the present document or not
#we'll se a lot of 'False' values because (of course) not all 2000 words will be on each sentence!
featuresets[0]
# Out:
# ({'contains(-)': False,
#   'contains(.)': True,
#   'contains(/)': False,
#   'contains(,)': True,
#   'contains(:)': True,
#   'contains(the)': True,
#   'contains(to)': True,
#   'contains(ect)': False,
#   'contains(and)': False,
#   'contains(@)': False,
#   'contains(of)': True,
#   'contains(a)': False,
#   'contains(for)': True,
#   'contains(you)': True,
#   'contains(in)': False,
#   'contains(is)': False,
#   'contains(this)': False,
#   'contains(hou)': False,
#   'contains(on)': False,
#   'contains(=)': False,
#   'contains(?)': False,
#   'contains(i)': True,
#   "contains(')": True,
#   'contains())': False,
#   'contains(()': False,
#   'contains(Subject)': True,
#   'contains(!)': False,
#   'contains(your)': False,
#   'contains(that)': False,
#   'contains(be)': True,
#   'contains(2000)': False,
#   'contains(enron)': False,
#   'contains(with)': False,
#   'contains(will)': True,
#   'contains(we)': False,
#   'contains(have)': False,
#   'contains(3)': False,
#   'contains(from)': False,
#   'contains($)': False,
#   'contains(s)': False,
#   'contains(as)': False,
#   'contains(at)': False,
#   'contains(are)': False,
#   'contains(it)': False,
#   'contains(by)': True,
#   'contains(please)': False,
#   'contains(not)': False,
#   'contains(``)': False,
#   'contains(if)': True,
#   'contains(1)': False,
#   'contains(or)': False,
#   'contains(com)': False,
#   'contains(_)': False,
#   'contains(*)': False,
#   'contains(;)': False,
#   'contains(me)': False,
#   'contains(2)': False,
#   'contains(e)': False,
#   'contains(%)': False,
#   'contains(00)': False,
#   'contains(#)': True,
#   'contains(all)': False,
#   'contains(d)': False,
#   'contains(our)': False,
#   'contains(>)': False,
#   'contains(subject)': False,
#   'contains(meter)': False,
#   'contains(can)': False,
#   'contains(am)': False,
#   'contains(pm)': False,
#   'contains(gas)': True,
#   'contains(cc)': False,
#   'contains(deal)': False,
#   'contains(any)': True,
#   'contains(0)': True,
#   'contains(http)': False,
#   'contains(99)': False,
#   'contains(000)': False,
#   'contains(no)': False,
#   'contains(has)': False,
#   'contains(corp)': False,
#   'contains(new)': False,
#   'contains(thanks)': False,
#   'contains(get)': False,
#   'contains(an)': False,
#   'contains(re)': False,
#   'contains(10)': False,
#   'contains(was)': False,
#   'contains(up)': False,
#   'contains(4)': False,
#   'contains(5)': False,
#   'contains(&)': False,
#   'contains(know)': False,
#   'contains(t)': False,
#   'contains(here)': False,
#   'contains(|)': False,
#   'contains(need)': False,
#   'contains(more)': False,
#   'contains(forwarded)': False,
#   'contains(03)': False,
#   'contains(out)': False,
#   'contains(12)': False,
#   'contains(do)': False,
#   'contains(p)': False,
#   'contains(only)': False,
#   'contains(may)': False,
#   'contains(daren)': False,
#   'contains(hpl)': False,
#   'contains(there)': False,
#   'contains(7)': False,
#   'contains(information)': False,
#   'contains(these)': False,
#   'contains(into)': False,
#   'contains(my)': False,
#   'contains(us)': False,
#   'contains(company)': False,
#   'contains(01)': False,
#   'contains(mmbtu)': False,
#   'contains(05)': False,
#   'contains(www)': False,
#   'contains(04)': False,
#   'contains(02)': False,
#   'contains(l)': False,
#   'contains(let)': False,
#   'contains(time)': False,
#   'contains(would)': False,
#   'contains(but)': True,
#   'contains(so)': False,
#   'contains(6)': False,
#   'contains(m)': False,
#   'contains(been)': False,
#   'contains(11)': False,
#   'contains(price)': False,
#   'contains(b)': False,
#   'contains(one)': True,
#   'contains(should)': False,
#   'contains(now)': False,
#   'contains(th)': False,
#   'contains(month)': False,
#   'contains(mail)': False,
#   'contains(contract)': False,
#   'contains(8)': False,
#   'contains(td)': False,
#   'contains(email)': False,
#   'contains(nbsp)': False,
#   'contains(sitara)': True,
#   'contains(what)': False,
#   'contains(see)': False,
#   'contains(20)': False,
#   'contains(j)': False,
#   'contains(])': False,
#   'contains([)': False,
#   'contains(which)': False,
#   'contains(day)': False,
#   'contains(x)': False,
#   'contains(also)': False,
#   'contains(15)': False,
#   'contains(volume)': False,
#   'contains(they)': False,
#   'contains(about)': False,
#   'contains(free)': False,
#   'contains(like)': False,
#   'contains(energy)': False,
#   'contains(c)': False,
#   'contains(deals)': False,
#   'contains(font)': False,
#   'contains(their)': False,
#   'contains(pills)': False,
#   'contains(some)': False,
#   'contains(change)': False,
#   'contains(ami)': False,
#   'contains(30)': False,
#   'contains(business)': False,
#   'contains(just)': False,
#   'contains(o)': False,
#   'contains(message)': False,
#   'contains(want)': False,
#   'contains(r)': False,
#   'contains(volumes)': False,
#   'contains(2004)': False,
#   'contains(over)': False,
#   'contains(attached)': False,
#   'contains(other)': False,
#   'contains(+)': False,
#   'contains(farmer)': False,
#   'contains(xls)': False,
#   'contains(09)': False,
#   'contains(its)': False,
#   'contains(questions)': False,
#   'contains(who)': False,
#   'contains(contact)': False,
#   'contains(9)': False,
#   'contains(when)': False,
#   'contains(make)': False,
#   'contains(width)': False,
#   'contains(report)': False,
#   'contains(25)': False,
#   'contains(60)': False,
#   'contains(call)': False,
#   'contains(06)': False,
#   'contains(list)': False,
#   'contains(click)': False,
#   'contains(back)': False,
#   'contains(money)': False,
#   'contains(f)': False,
#   'contains(100)': False,
#   'contains(texas)': False,
#   'contains(could)': False,
#   'contains(nom)': False,
#   'contains(set)': False,
#   'contains(chokshi)': False,
#   'contains(inc)': False,
#   'contains(robert)': False,
#   'contains(he)': False,
#   'contains(height)': False,
#   'contains(following)': False,
#   'contains(order)': False,
#   'contains(24)': False,
#   'contains(50)': False,
#   'contains(how)': False,
#   'contains(forward)': False,
#   'contains(production)': False,
#   'contains(08)': False,
#   'contains(w)': False,
#   'contains(below)': False,
#   'contains(them)': False,
#   'contains(january)': False,
#   'contains(21)': False,
#   'contains(per)': False,
#   'contains(today)': False,
#   'contains(statements)': False,
#   'contains(march)': False,
#   'contains(best)': False,
#   'contains(sale)': False,
#   'contains(ena)': False,
#   'contains(number)': False,
#   'contains(k)': False,
#   'contains(available)': False,
#   'contains(first)': False,
#   'contains(g)': False,
#   'contains(through)': False,
#   'contains(take)': True,
#   'contains(31)': False,
#   'contains(system)': False,
#   'contains(align)': False,
#   'contains(sent)': False,
#   'contains(were)': False,
#   'contains(go)': False,
#   'contains(days)': False,
#   'contains(she)': False,
#   'contains(help)': False,
#   'contains(don)': False,
#   'contains(management)': False,
#   'contains(98)': False,
#   'contains(stock)': False,
#   'contains(jackie)': False,
#   'contains(u)': False,
#   'contains(v)': False,
#   'contains(tr)': False,
#   'contains(online)': False,
#   'contains(23)': False,
#   'contains(ticket)': True,
#   'contains(changes)': False,
#   'contains(june)': False,
#   'contains(size)': False,
#   'contains(within)': False,
#   'contains(n)': False,
#   'contains(14)': False,
#   'contains(flow)': False,
#   'contains(border)': False,
#   'contains(info)': False,
#   'contains(last)': False,
#   'contains(18)': False,
#   'contains(nd)': False,
#   'contains(well)': False,
#   'contains(than)': True,
#   'contains(group)': False,
#   'contains(16)': False,
#   'contains(most)': False,
#   'contains(gary)': False,
#   'contains(address)': False,
#   'contains(service)': False,
#   'contains(next)': False,
#   'contains(had)': False,
#   'contains(team)': False,
#   'contains(transport)': False,
#   'contains(pec)': False,
#   'contains(his)': False,
#   'contains(effective)': False,
#   'contains(work)': False,
#   'contains(each)': False,
#   'contains(color)': False,
#   'contains(april)': False,
#   'contains(due)': False,
#   'contains(face)': False,
#   'contains(use)': False,
#   'contains(account)': False,
#   'contains(buy)': False,
#   'contains(sales)': False,
#   'contains(looking)': False,
#   'contains(69)': False,
#   'contains(22)': False,
#   'contains(nomination)': False,
#   'contains(many)': False,
#   'contains(office)': False,
#   'contains(without)': False,
#   'contains(after)': False,
#   'contains(offer)': False,
#   'contains(microsoft)': False,
#   "contains('')": False,
#   'contains(net)': False,
#   'contains(services)': False,
#   'contains(week)': False,
#   'contains(prices)': False,
#   'contains(name)': False,
#   'contains(before)': False,
#   'contains(same)': False,
#   'contains(because)': False,
#   'contains(63)': False,
#   'contains(year)': False,
#   'contains(19)': False,
#   'contains(feb)': False,
#   'contains(save)': False,
#   'contains(delivery)': False,
#   'contains(17)': False,
#   'contains(line)': False,
#   'contains(thank)': False,
#   'contains(link)': False,
#   'contains(send)': False,
#   'contains(aimee)': False,
#   'contains(special)': False,
#   'contains(13)': False,
#   'contains(date)': False,
#   'contains(desk)': False,
#   'contains(million)': False,
#   'contains(27)': False,
#   'contains(being)': False,
#   'contains(file)': False,
#   'contains(40)': False,
#   'contains(investment)': False,
#   'contains(href)': False,
#   'contains(src)': False,
#   'contains(off)': True,
#   'contains(products)': False,
#   'contains(90)': False,
#   'contains(made)': False,
#   'contains(br)': False,
#   'contains(pat)': False,
#   'contains(future)': False,
#   'contains(needs)': True,
#   'contains(then)': False,
#   'contains(where)': False,
#   'contains(software)': False,
#   'contains(161)': False,
#   'contains(two)': False,
#   'contains(give)': False,
#   'contains(steve)': False,
#   'contains(windows)': False,
#   'contains(above)': False,
#   'contains(meeting)': False,
#   'contains(process)': False,
#   'contains(120)': False,
#   'contains(based)': False,
#   'contains(does)': False,
#   'contains(h)': False,
#   'contains(place)': False,
#   'contains(stop)': False,
#   'contains(jan)': False,
#   'contains(marketing)': False,
#   'contains(viagra)': False,
#   'contains(data)': False,
#   'contains(george)': False,
#   'contains(did)': False,
#   'contains(good)': False,
#   'contains(computron)': False,
#   'contains(check)': False,
#   'contains(tom)': False,
#   'contains(very)': False,
#   'contains(such)': False,
#   'contains(internet)': False,
#   'contains(people)': False,
#   'contains(look)': False,
#   'contains(securities)': False,
#   'contains(professional)': False,
#   'contains(hplc)': False,
#   'contains(28)': False,
#   'contains(anita)': False,
#   'contains(29)': False,
#   'contains(julie)': False,
#   'contains(america)': False,
#   'contains(site)': False,
#   'contains(find)': False,
#   'contains(receive)': False,
#   'contains(down)': False,
#   'contains(risk)': True,
#   'contains(reply)': False,
#   'contains(under)': False,
#   'contains(mary)': False,
#   'contains(45)': False,
#   'contains(pg)': False,
#   'contains(international)': False,
#   'contains(market)': False,
#   'contains(february)': False,
#   'contains(world)': False,
#   'contains(susan)': False,
#   'contains(tickets)': False,
#   'contains(since)': False,
#   'contains(meters)': False,
#   'contains(much)': False,
#   'contains(purchase)': False,
#   'contains(sure)': False,
#   'contains(those)': False,
#   'contains(young)': False,
#   'contains(howard)': False,
#   'contains(provide)': False,
#   'contains(home)': False,
#   'contains(rates)': False,
#   'contains(44)': False,
#   'contains(07)': False,
#   'contains(unify)': False,
#   'contains(high)': False,
#   'contains(26)': False,
#   'contains(pipeline)': False,
#   'contains(ll)': False,
#   'contains(her)': False,
#   'contains(\x01)': False,
#   'contains(development)': False,
#   'contains(brenda)': False,
#   'contains(xp)': False,
#   'contains(smith)': False,
#   'contains(visit)': False,
#   'contains(center)': False,
#   'contains(north)': False,
#   'contains(both)': False,
#   'contains(again)': False,
#   'contains(right)': False,
#   'contains(st)': False,
#   'contains(request)': False,
#   'contains(problem)': False,
#   'contains(great)': False,
#   'contains(total)': False,
#   'contains(activity)': False,
#   'contains(financial)': False,
#   'contains(point)': False,
#   'contains(needed)': False,
#   'contains(`)': False,
#   'contains(operations)': False,
#   'contains(2003)': False,
#   'contains(companies)': False,
#   'contains(product)': False,
#   'contains(ve)': True,
#   'contains(friday)': False,
#   'contains(meds)': False,
#   'contains(end)': False,
#   'contains(still)': False,
#   'contains(id)': False,
#   'contains(80)': False,
#   'contains(less)': False,
#   'contains(issue)': False,
#   'contains(1999)': False,
#   'contains(lisa)': False,
#   'contains(daily)': True,
#   'contains(show)': False,
#   'contains(low)': False,
#   'contains(stephanie)': False,
#   'contains(713)': False,
#   'contains(plant)': False,
#   'contains(note)': False,
#   'contains(noms)': False,
#   'contains(must)': False,
#   'contains(news)': False,
#   'contains(keep)': False,
#   'contains(full)': False,
#   'contains(quality)': False,
#   'contains(trading)': False,
#   'contains(html)': False,
#   'contains(lloyd)': False,
#   'contains(rate)': False,
#   'contains(index)': False,
#   'contains(transaction)': False,
#   'contains(support)': False,
#   'contains(revised)': False,
#   'contains(own)': False,
#   'contains(adobe)': False,
#   'contains(entex)': False,
#   'contains(additional)': False,
#   'contains(security)': False,
#   'contains(copy)': False,
#   'contains(prescription)': False,
#   'contains(ces)': False,
#   'contains(global)': True,
#   'contains(once)': False,
#   'contains(issues)': False,
#   'contains(performance)': False,
#   'contains(paliourg)': False,
#   'contains(increase)': False,
#   'contains(currently)': False,
#   'contains(32)': False,
#   'contains(fred)': False,
#   'contains(camp)': False,
#   'contains(hi)': False,
#   'contains(offers)': False,
#   'contains(remove)': False,
#   'contains(long)': False,
#   'contains(pops)': False,
#   'contains(think)': False,
#   'contains(going)': False,
#   'contains(further)': False,
#   'contains(numbers)': False,
#   'contains(agreement)': False,
#   'contains(via)': False,
#   'contains(herod)': False,
#   'contains(hours)': False,
#   'contains(come)': False,
#   'contains(until)': False,
#   'contains(every)': False,
#   'contains(500)': False,
#   'contains(access)': False,
#   'contains(fyi)': False,
#   'contains(bob)': False,
#   'contains(bgcolor)': False,
#   'contains(luong)': False,
#   'contains(used)': False,
#   'contains(sell)': False,
#   'contains(put)': False,
#   'contains(months)': False,
#   'contains(someone)': False,
#   'contains(control)': False,
#   'contains(while)': False,
#   'contains(using)': False,
#   'contains(position)': False,
#   'contains(review)': False,
#   'contains(prior)': False,
#   'contains(dollars)': False,
#   'contains(stella)': False,
#   'contains(working)': False,
#   'contains(done)': False,
#   'contains(clynes)': False,
#   'contains(possible)': False,
#   'contains(midcon)': False,
#   'contains(part)': False,
#   'contains(eastrans)': False,
#   'contains(cd)': False,
#   'contains(believe)': False,
#   'contains(soon)': False,
#   'contains(notice)': False,
#   'contains(contracts)': False,
#   'contains(start)': False,
#   'contains(results)': False,
#   'contains(limited)': False,
#   'contains(act)': False,
#   'contains(details)': False,
#   'contains(counterparty)': False,
#   'contains(received)': False,
#   'contains(michael)': False,
#   'contains(cialis)': False,
#   'contains(allen)': False,
#   'contains(pay)': False,
#   'contains(accounting)': False,
#   'contains(35)': False,
#   'contains(content)': False,
#   'contains(health)': False,
#   'contains(biz)': False,
#   'contains(95)': False,
#   'contains(works)': False,
#   'contains(pro)': False,
#   'contains(charlotte)': False,
#   'contains(web)': False,
#   'contains(meyers)': False,
#   'contains(weight)': False,
#   'contains(required)': False,
#   'contains(mg)': False,
#   'contains(brian)': False,
#   'contains(project)': False,
#   'contains(duke)': False,
#   'contains(retail)': False,
#   'contains(cash)': False,
#   'contains(newsletter)': False,
#   'contains(got)': False,
#   'contains(even)': False,
#   'contains(life)': False,
#   'contains(stacey)': False,
#   'contains(storage)': False,
#   'contains(strong)': False,
#   'contains(jpg)': False,
#   'contains(124)': False,
#   'contains(natural)': False,
#   'contains(monday)': False,
#   'contains(reports)': False,
#   'contains(scott)': False,
#   'contains(customer)': False,
#   'contains(correct)': False,
#   'contains(current)': False,
#   'contains(survey)': False,
#   'contains(ranch)': False,
#   'contains(manager)': False,
#   'contains(loss)': False,
#   'contains(real)': False,
#   'contains(dec)': False,
#   'contains(power)': False,
#   'contains(fax)': False,
#   'contains(section)': False,
#   'contains(during)': False,
#   'contains(allocated)': False,
#   'contains(resources)': False,
#   'contains(easy)': False,
#   'contains(y)': False,
#   'contains(east)': False,
#   'contains(including)': False,
#   'contains(interest)': False,
#   'contains(type)': False,
#   'contains(phone)': False,
#   'contains(thu)': False,
#   'contains(de)': False,
#   'contains(feel)': False,
#   'contains(private)': False,
#   'contains(stocks)': False,
#   'contains(vance)': False,
#   'contains(why)': False,
#   'contains(carthage)': False,
#   'contains(hsc)': False,
#   'contains(follow)': False,
#   'contains(advice)': False,
#   'contains(top)': False,
#   'contains(commercial)': False,
#   'contains(gif)': False,
#   'contains(000000)': False,
#   'contains(way)': False,
#   'contains(july)': False,
#   'contains(never)': False,
#   'contains(able)': False,
#   'contains(scheduled)': False,
#   'contains(moopid)': False,
#   'contains(hotlist)': False,
#   'contains(complete)': False,
#   'contains(drugs)': False,
#   'contains(getting)': False,
#   'contains(city)': False,
#   'contains(lannou)': False,
#   'contains(corporation)': False,
#   'contains(cost)': False,
#   'contains(read)': False,
#   'contains(pain)': False,
#   'contains(div)': False,
#   'contains(oil)': False,
#   'contains(however)': False,
#   'contains(program)': False,
#   'contains(removed)': False,
#   'contains(page)': False,
#   'contains(move)': False,
#   'contains(include)': False,
#   'contains(houston)': False,
#   'contains(man)': False,
#   'contains(costs)': False,
#   'contains(old)': False,
#   'contains(tuesday)': False,
#   'contains(receipt)': False,
#   'contains(said)': False,
#   'contains(rc)': False,
#   'contains(release)': False,
#   'contains(body)': False,
#   'contains(table)': False,
#   'contains(valid)': False,
#   'contains(too)': False,
#   'contains(david)': False,
#   'contains(provided)': False,
#   'contains(taylor)': False,
#   'contains(country)': False,
#   'contains(error)': False,
#   'contains(try)': False,
#   'contains(xanax)': False,
#   'contains(form)': False,
#   'contains(open)': False,
#   'contains(mar)': False,
#   'contains(necessary)': False,
#   'contains(co)': False,
#   'contains(htmlimg)': False,
#   'contains(another)': False,
#   'contains(anything)': False,
#   'contains(better)': False,
#   'contains(suite)': False,
#   'contains(shipping)': False,
#   'contains(continue)': False,
#   'contains(past)': False,
#   'contains(calls)': False,
#   'contains(\\)': False,
#   'contains(buyback)': False,
#   'contains(clear)': False,
#   'contains(party)': False,
#   'contains(third)': False,
#   'contains(regarding)': False,
#   'contains(update)': False,
#   'contains(images)': False,
#   'contains(book)': False,
#   'contains(yet)': False,
#   'contains(zero)': False,
#   'contains(bryan)': False,
#   'contains(original)': False,
#   'contains(200)': False,
#   'contains(cotton)': False,
#   'contains(55)': False,
#   'contains(ever)': False,
#   'contains(systems)': False,
#   'contains(investing)': False,
#   'contains(36)': False,
#   'contains(source)': False,
#   'contains(add)': False,
#   'contains(morning)': False,
#   'contains(flowed)': False,
#   'contains(melissa)': False,
#   'contains(fuels)': False,
#   'contains(path)': False,
#   'contains(spam)': False,
#   'contains(between)': False,
#   'contains(always)': False,
#   'contains(mark)': False,
#   'contains(regards)': False,
#   'contains(super)': False,
#   'contains(valium)': False,
#   'contains(united)': False,
#   'contains(ken)': False,
#   'contains(everyone)': False,
#   'contains(215)': False,
#   'contains(lst)': False,
#   'contains(everything)': False,
#   'contains(application)': False,
#   'contains(800)': False,
#   'contains(few)': False,
#   'contains(300)': False,
#   'contains(something)': False,
#   'contains(love)': False,
#   'contains(70)': False,
#   'contains(found)': False,
#   'contains(case)': False,
#   'contains(term)': False,
#   'contains(ensure)': False,
#   'contains(charge)': False,
#   'contains(fill)': False,
#   'contains(three)': False,
#   'contains(shares)': False,
#   'contains(img)': False,
#   'contains(jennifer)': False,
#   'contains(box)': False,
#   'contains(either)': False,
#   'contains(left)': False,
#   'contains(valley)': False,
#   'contains(cause)': False,
#   'contains(transfer)': False,
#   'contains(cheap)': False,
#   'contains(zone)': False,
#   'contains(estimates)': False,
#   'contains(sally)': False,
#   'contains(department)': False,
#   'contains(php)': False,
#   'contains(server)': False,
#   'contains(south)': False,
#   'contains(technology)': False,
#   'contains(aol)': False,
#   'contains(encina)': False,
#   'contains(weekend)': False,
#   'contains(acton)': False,
#   'contains(close)': False,
#   'contains(little)': False,
#   'contains(yourself)': False,
#   'contains(duty)': False,
#   'contains(already)': False,
#   'contains(75)': False,
#   'contains(cs)': False,
#   'contains(wish)': False,
#   'contains(public)': False,
#   'contains(mobile)': False,
#   'contains(late)': False,
#   'contains(hanks)': False,
#   'contains(communications)': False,
#   'contains(music)': False,
#   'contains(equistar)': False,
#   'contains(john)': False,
#   'contains(created)': False,
#   'contains(industry)': False,
#   'contains(sherlyn)': False,
#   'contains(different)': False,
#   'contains(fact)': False,
#   'contains(trade)': False,
#   'contains(~)': False,
#   'contains(direct)': False,
#   'contains(drive)': False,
#   'contains(years)': False,
#   'contains(quick)': False,
#   'contains(pricing)': False,
#   'contains(browser)': False,
#   'contains(second)': False,
#   'contains(customers)': False,
#   'contains(photoshop)': False,
#   'contains(head)': False,
#   'contains(field)': False,
#   'contains(text)': False,
#   'contains(thomas)': False,
#   'contains(ms)': False,
#   'contains(side)': False,
#   'contains(longer)': False,
#   'contains(around)': False,
#   'contains(worldwide)': False,
#   'contains(anyone)': False,
#   'contains(37)': False,
#   'contains(credit)': False,
#   'contains(lose)': False,
#   'contains(states)': False,
#   'contains(generic)': False,
#   'contains(morris)': False,
#   'contains(gco)': False,
#   'contains(reliantenergy)': False,
#   'contains(remember)': False,
#   'contains(56)': False,
#   'contains(canada)': False,
#   'contains(really)': False,
#   'contains(view)': False,
#   'contains(play)': False,
#   'contains(registered)': False,
#   'contains(devon)': False,
#   'contains(problems)': False,
#   'contains(publisher)': False,
#   'contains(him)': False,
#   'contains(wanted)': False,
#   'contains(else)': False,
#   'contains(december)': False,
#   'contains(etc)': False,
#   'contains(012)': False,
#   'contains(sold)': False,
#   'contains(paste)': False,
#   'contains(hey)': False,
#   'contains(methanol)': False,
#   'contains(major)': False,
#   'contains(soft)': False,
#   'contains(men)': False,
#   'contains(fuel)': False,
#   'contains(gcs)': False,
#   'contains(cec)': False,
#   'contains(unsubscribe)': False,
#   'contains(james)': False,
#   'contains(ees)': False,
#   'contains(schedule)': False,
#   'contains(lauri)': False,
#   'contains(boas)': False,
#   'contains(gomes)': False,
#   'contains(plan)': False,
#   'contains(logistics)': False,
#   'contains(33)': False,
#   'contains(reason)': False,
#   'contains(press)': False,
#   'contains(actual)': False,
#   'contains(52)': False,
#   'contains(person)': False,
#   'contains(withers)': False,
#   'contains(fund)': False,
#   'contains(family)': False,
#   'contains(cf)': False,
#   'contains(dear)': False,
#   'contains(thursday)': False,
#   'contains(secure)': False,
#   'contains(key)': False,
#   'contains(training)': False,
#   'contains(features)': False,
#   'contains(hawkins)': False,
#   'contains(growth)': False,
#   'contains(beaumont)': False,
#   'contains(compliance)': False,
#   'contains(reveffo)': False,
#   'contains(graves)': False,
#   'contains(plus)': False,
#   'contains(version)': False,
#   'contains(small)': False,
#   'contains(swing)': False,
#   'contains(bank)': False,
#   'contains(hard)': False,
#   'contains(medications)': False,
#   'contains(kind)': False,
#   'contains(area)': False,
#   'contains(allow)': False,
#   'contains(solution)': False,
#   'contains(})': False,
#   'contains(level)': False,
#   'contains(material)': False,
#   'contains(34)': False,
#   'contains(user)': False,
#   'contains(allocation)': False,
#   'contains(im)': False,
#   'contains(personal)': False,
#   'contains(teco)': False,
#   'contains(president)': False,
#   'contains(ali)': False,
#   'contains(darial)': False,
#   'contains(lee)': True,
#   'contains(kenneth)': False,
#   'contains(rita)': False,
#   'contains(valero)': False,
#   'contains(learn)': False,
#   'contains(carlos)': False,
#   'contains(spot)': False,
#   'contains(rd)': False,
#   'contains(mid)': False,
#   'contains(48)': False,
#   'contains(meet)': False,
#   'contains(legal)': False,
#   'contains(bill)': False,
#   'contains(approximately)': False,
#   'contains(download)': False,
#   'contains(gr)': False,
#   'contains(trevino)': False,
#   'contains(fw)': False,
#   'contains(shut)': False,
#   'contains(·)': False,
#   'contains(0310041)': False,
#   'contains(king)': False,
#   'contains(aware)': False,
#   'contains(cut)': False,
#   'contains(amount)': False,
#   'contains(sex)': False,
#   'contains(experience)': False,
#   'contains(doctor)': False,
#   'contains(nominations)': False,
#   'contains(making)': False,
#   'contains(panenergy)': False,
#   'contains(hope)': False,
#   'contains(called)': False,
#   'contains(thing)': False,
#   'contains(therefore)': False,
#   'contains(tell)': False,
#   'contains(mr)': False,
#   'contains(network)': False,
#   'contains(updated)': False,
#   'contains(might)': False,
#   'contains(imbalance)': False,
#   'contains(supply)': False,
#   'contains(property)': False,
#   'contains(prize)': False,
#   'contains(cds)': False,
#   'contains(wellhead)': False,
#   'contains(things)': False,
#   'contains(58)': False,
#   'contains(42)': False,
#   'contains(paid)': False,
#   'contains(addition)': False,
#   'contains(begin)': False,
#   'contains(39)': False,
#   'contains(events)': False,
#   'contains(weeks)': False,
#   'contains(latest)': False,
#   'contains(several)': False,
#   'contains(interested)': False,
#   'contains(49)': False,
#   'contains(shows)': False,
#   'contains(tina)': False,
#   'contains(safe)': False,
#   'contains(related)': False,
#   'contains(directly)': False,
#   'contains(hello)': False,
#   'contains(yvette)': False,
#   'contains(china)': False,
#   'contains(federal)': False,
#   'contains(whole)': False,
#   'contains(expected)': False,
#   'contains(options)': False,
#   'contains(pc)': False,
#   'contains(iit)': False,
#   'contains(demokritos)': False,
#   'contains(approved)': False,
#   'contains(dave)': False,
#   'contains(gold)': False,
#   'contains(title)': False,
#   'contains(neuweiler)': False,
#   'contains(971)': False,
#   'contains(mx)': False,
#   'contains(0424040)': False,
#   'contains(ftar)': False,
#   'contains(given)': False,
#   'contains(feedback)': False,
#   'contains(research)': False,
#   'contains(38)': False,
#   'contains(bridge)': False,
#   'contains(fast)': False,
#   'contains(create)': False,
#   'contains(confirm)': False,
#   'contains(understand)': False,
#   'contains(thru)': False,
#   'contains(thought)': False,
#   'contains(lp)': False,
#   'contains(status)': False,
#   'contains(letter)': False,
#   'contains(doing)': False,
#   'contains(having)': False,
#   'contains(monthly)': False,
#   'contains(large)': False,
#   'contains(away)': False,
#   'contains(kimberly)': False,
#   'contains(q)': False,
#   'contains(follows)': False,
#   'contains(yahoo)': False,
#   'contains({)': False,
#   'contains(takes)': False,
#   'contains(exchange)': False,
#   ...},
#  'ham')

# %%
#We are ready now to do machine learning using the unigram list we just created
#we use a Naive Bayes classifier with 5-fold cross validation for training on sentiments using unigrams

start = time.time()
num_split = 5
kf = KFold(n_splits = num_split)
sum = 0
prec = 0
recall = 0

for train, test in kf.split(featuresets):
    train_data = np.array(featuresets)[train]
    test_data = np.array(featuresets)[test]
    classifier = nltk.NaiveBayesClassifier.train(train_data)
    sum += nltk.classify.accuracy(classifier, test_data)
    
    #calculating precision and recall 
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)

    for i, (feats, label) in enumerate(test_data):
        refsets[label].add(i)
        observed = classifier.classify(feats)
        testsets[observed].add(i)
    
    prec += nltk.precision(refsets['spam'], testsets['spam'])
    recall += nltk.recall(refsets['spam'], testsets['spam'])

#storing the score in a variable 
acc = sum/num_split
avg_precision = prec/num_split
avg_recall = recall/num_split

end = time.time()
print("Processing Time: {0:.2f} seconds".format(end - start))

#let's see the accuracy score for this new classifier
print("Accuracy:", round(acc,4))
print("Precision:", round(avg_precision,4))
print("Recall:", round(avg_recall,4))
# Out:
# Processing Time: 29.18 seconds
# Accuracy: 0.9485
# Precision: 0.9079
# Recall: 0.999

# %%
## EXPERIMENT 1: USING BIGRAMS INSTEAD OF UNIGRAMS ##

# We will now create a new feature: bigrams
#we'll use the code we already know from class labs 

from nltk.collocations import *
import re

#data cleaning and preprocessing
stopwords = nltk.corpus.stopwords.words('english')

def alpha(w):
    pattern = re.compile('^[^a-z]+$')
    if(pattern.match(w)):
        return True
    else:
        return False

#creating bigrams features for the corpus and applying cleaning steps
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(all_words)
finder.apply_word_filter(alpha)
finder.apply_word_filter(lambda w: w in stopwords)
scored = finder.score_ngrams(bigram_measures.raw_freq)
scored[:10]
# Out:
# [(('ect', 'cc'), 0.001047708058603369),
#  (('ect', 'subject'), 0.0005868018658165508),
#  (('daren', 'j'), 0.00044170176808736733),
#  (('j', 'farmer'), 0.00044170176808736733),
#  (('ami', 'chokshi'), 0.00043743411815415606),
#  (('please', 'let'), 0.00037982084405580377),
#  (('would', 'like'), 0.0002325869213600147),
#  (('xls', 'Subject'), 0.00023045309639340905),
#  (('e', 'lloyd'), 0.00020911484672735264),
#  (('robert', 'e'), 0.00020911484672735264)]

# %%
#extracting clean bigrams (no frequency information)
bigram_features = [bigram for (bigram, count) in scored[:2000]]
#printing the first 30 for confirmation
bigram_features[:30]
# Out:
# [('ect', 'cc'),
#  ('ect', 'subject'),
#  ('daren', 'j'),
#  ('j', 'farmer'),
#  ('ami', 'chokshi'),
#  ('please', 'let'),
#  ('would', 'like'),
#  ('xls', 'Subject'),
#  ('e', 'lloyd'),
#  ('robert', 'e'),
#  ('enron', 'cc'),
#  ('b', 'camp'),
#  ('howard', 'b'),
#  ('anita', 'luong'),
#  ('attached', 'file'),
#  ('north', 'america'),
#  ('td', 'td'),
#  ('see', 'attached'),
#  ('pat', 'clynes'),
#  ('brenda', 'f'),
#  ('f', 'herod'),
#  ('enron', 'north'),
#  ('looking', 'statements'),
#  ('jackie', 'young'),
#  ('julie', 'meyers'),
#  ('america', 'corp'),
#  ('aimee', 'lannou'),
#  ('tr', 'td'),
#  ('jpg', 'width'),
#  ('cotton', 'valley')]

# %%
#after finding all bigrams of the corpus (i.e. the bigram feature of the corpus)
#we create a function that checks if those feature bigrams are present on each specific document
#exactly as we did with unigrams

def bi_document_features(document, bigram_features):
    document_words = list(nltk.bigrams(document))
    features = {}
    for word in bigram_features:
        #boolean logic will retunt 'True' if there is a match, or 'False' if not
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
#applying the function to our documents
featuresets2 = [(bi_document_features(d, bigram_features), c) for (d, c) in emaildocs]

#seeing the featureset for the first document
featuresets2[0]
# Out:
# ({"contains(('ect', 'cc'))": False,
#   "contains(('ect', 'subject'))": False,
#   "contains(('daren', 'j'))": False,
#   "contains(('j', 'farmer'))": False,
#   "contains(('ami', 'chokshi'))": False,
#   "contains(('please', 'let'))": False,
#   "contains(('would', 'like'))": False,
#   "contains(('xls', 'Subject'))": False,
#   "contains(('e', 'lloyd'))": False,
#   "contains(('robert', 'e'))": False,
#   "contains(('enron', 'cc'))": False,
#   "contains(('b', 'camp'))": False,
#   "contains(('howard', 'b'))": False,
#   "contains(('anita', 'luong'))": False,
#   "contains(('attached', 'file'))": False,
#   "contains(('north', 'america'))": False,
#   "contains(('td', 'td'))": False,
#   "contains(('see', 'attached'))": False,
#   "contains(('pat', 'clynes'))": False,
#   "contains(('brenda', 'f'))": False,
#   "contains(('f', 'herod'))": False,
#   "contains(('enron', 'north'))": False,
#   "contains(('looking', 'statements'))": False,
#   "contains(('jackie', 'young'))": False,
#   "contains(('julie', 'meyers'))": False,
#   "contains(('america', 'corp'))": False,
#   "contains(('aimee', 'lannou'))": False,
#   "contains(('tr', 'td'))": False,
#   "contains(('jpg', 'width'))": False,
#   "contains(('cotton', 'valley'))": False,
#   "contains(('please', 'call'))": False,
#   "contains(('fuels', 'cotton'))": False,
#   "contains(('make', 'sure'))": False,
#   "contains(('tom', 'acton'))": False,
#   "contains(('xp', 'professional'))": False,
#   "contains(('windows', 'xp'))": False,
#   "contains(('sitara', 'deal'))": False,
#   "contains(('gas', 'marketing'))": False,
#   "contains(('fred', 'boas'))": False,
#   "contains(('stephanie', 'gomes'))": False,
#   "contains(('tr', 'tr'))": False,
#   "contains(('email', 'address'))": False,
#   "contains(('l', 'taylor'))": False,
#   "contains(('melissa', 'graves'))": False,
#   "contains(('vance', 'l'))": False,
#   "contains(('money', 'back'))": False,
#   "contains(('retail', 'price'))": False,
#   "contains(('charlotte', 'hawkins'))": False,
#   "contains(('duty', 'free'))": False,
#   "contains(('l', 'morris'))": False,
#   "contains(('stella', 'l'))": False,
#   "contains(('ali', 'duty'))": False,
#   "contains(('deal', 'tickets'))": False,
#   "contains(('enron', 'communications'))": False,
#   "contains(('enron', 'subject'))": False,
#   "contains(('investment', 'advice'))": False,
#   "contains(('microsoft', 'office'))": False,
#   "contains(('adobe', 'photoshop'))": False,
#   "contains(('best', 'regards'))": False,
#   "contains(('deal', 'ticket'))": False,
#   "contains(('natural', 'gas'))": False,
#   "contains(('rita', 'wynne'))": False,
#   "contains(('tina', 'valadez'))": False,
#   "contains(('forward', 'looking'))": False,
#   "contains(('p', 'align'))": False,
#   "contains(('please', 'contact'))": False,
#   "contains(('com', 'cc'))": False,
#   "contains(('encina', 'gas'))": False,
#   "contains(('new', 'deal'))": False,
#   "contains(('risk', 'management'))": False,
#   "contains(('third', 'party'))": False,
#   "contains(('george', 'weissman'))": False,
#   "contains(('next', 'week'))": False,
#   "contains(('font', 'color'))": False,
#   "contains(('gif', 'width'))": False,
#   "contains(('office', 'xp'))": False,
#   "contains(('please', 'send'))": False,
#   "contains(('volume', 'management'))": False,
#   "contains(('feel', 'free'))": False,
#   "contains(('low', 'price'))": False,
#   "contains(('sherlyn', 'schumack'))": False,
#   "contains(('stacey', 'neuweiler'))": False,
#   "contains(('steve', 'holmes'))": False,
#   "contains(('td', 'width'))": False,
#   "contains(('united', 'states'))": False,
#   "contains(('bryan', 'hull'))": False,
#   "contains(('font', 'face'))": False,
#   "contains(('html', 'Subject'))": False,
#   "contains(('josey', 'ranch'))": False,
#   "contains(('please', 'give'))": False,
#   "contains(('please', 'see'))": False,
#   "contains(('thu', 'nguyen'))": False,
#   "contains(('without', 'notice'))": False,
#   "contains(('div', 'align'))": False,
#   "contains(('gas', 'daily'))": True,
#   "contains(('information', 'provided'))": False,
#   "contains(('kenneth', 'seaman'))": False,
#   "contains(('kimberly', 'vaughn'))": False,
#   "contains(('microsoft', 'windows'))": False,
#   "contains(('bruce', 'mcmills'))": False,
#   "contains(('susan', 'smith'))": False,
#   "contains(('bob', 'withers'))": False,
#   "contains(('darial', 'color'))": False,
#   "contains(('please', 'note'))": False,
#   "contains(('securities', 'act'))": False,
#   "contains(('special', 'offers'))": False,
#   "contains(('htmlimg', 'border'))": False,
#   "contains(('king', 'ranch'))": False,
#   "contains(('scott', 'mills'))": False,
#   "contains(('center', 'width'))": False,
#   "contains(('deal', 'number'))": False,
#   "contains(('p', 'p'))": False,
#   "contains(('verdana', 'size'))": False,
#   "contains(('contact', 'information'))": False,
#   "contains(('daren', 'farmer'))": False,
#   "contains(('full', 'story'))": False,
#   "contains(('gas', 'control'))": False,
#   "contains(('lisa', 'csikos'))": False,
#   "contains(('original', 'message'))": False,
#   "contains(('td', 'bgcolor'))": False,
#   "contains(('vlt', 'x'))": False,
#   "contains(('energy', 'operations'))": False,
#   "contains(('hsc', 'less'))": False,
#   "contains(('l', 'papayoti'))": False,
#   "contains(('lee', 'l'))": False,
#   "contains(('please', 'click'))": False,
#   "contains(('world', 'wide'))": False,
#   "contains(('com', 'Subject'))": False,
#   "contains(('duke', 'energy'))": False,
#   "contains(('let', 'us'))": False,
#   "contains(('mary', 'solmonson'))": False,
#   "contains(('per', 'day'))": False,
#   "contains(('please', 'feel'))": False,
#   "contains(('sarco', 'lateral'))": False,
#   "contains(('stop', 'date'))": False,
#   "contains(('td', 'colspan'))": False,
#   "contains(('weight', 'loss'))": False,
#   "contains(('donald', 'p'))": False,
#   "contains(('img', 'src'))": False,
#   "contains(('last', 'week'))": False,
#   "contains(('midcon', 'texas'))": False,
#   "contains(('p', 'reinhardt'))": False,
#   "contains(('pain', 'relief'))": False,
#   "contains(('prescription', 'required'))": False,
#   "contains(('robert', 'superty'))": False,
#   "contains(('subject', 'line'))": False,
#   "contains(('visit', 'us'))": False,
#   "contains(('clear', 'lake'))": False,
#   "contains(('corel', 'draw'))": False,
#   "contains(('differ', 'materially'))": False,
#   "contains(('equistar', 'deal'))": False,
#   "contains(('george', 'grant'))": False,
#   "contains(('hpl', 'iferc'))": False,
#   "contains(('information', 'remove'))": False,
#   "contains(('last', 'month'))": False,
#   "contains(('please', 'reply'))": False,
#   "contains(('text', 'format'))": False,
#   "contains(('gas', 'nomination'))": False,
#   "contains(('please', 'advise'))": False,
#   "contains(('please', 'make'))": False,
#   "contains(('td', 'valign'))": False,
#   "contains(('availability', 'subject'))": False,
#   "contains(('beaumont', 'methanol'))": False,
#   "contains(('br', 'br'))": False,
#   "contains(('com', 'dell'))": False,
#   "contains(('com', 'prices'))": False,
#   "contains(('commercial', 'e'))": False,
#   "contains(('considered', 'spam'))": False,
#   "contains(('could', 'cause'))": False,
#   "contains(('federal', 'legislation'))": False,
#   "contains(('format', 'reply'))": False,
#   "contains(('free', 'zone'))": False,
#   "contains(('iii', 'passed'))": False,
#   "contains(('inherent', 'conflict'))": False,
#   "contains(('jebel', 'ali'))": False,
#   "contains(('mmbtu', 'per'))": False,
#   "contains(('nom', 'change'))": False,
#   "contains(('one', 'stop'))": False,
#   "contains(('plain', 'text'))": False,
#   "contains(('please', 'take'))": False,
#   "contains(('products', 'may'))": False,
#   "contains(('reason', 'would'))": False,
#   "contains(('remove', 'instructions'))": False,
#   "contains(('sales', 'department'))": False,
#   "contains(('sea', 'robin'))": False,
#   "contains(('somehow', 'gotten'))": False,
#   "contains(('special', 'offer'))": False,
#   "contains(('stretch', 'brennan'))": False,
#   "contains(('th', 'u'))": False,
#   "contains(('title', 'iii'))": False,
#   "contains(('voice', 'mail'))": False,
#   "contains(('additional', 'information'))": False,
#   "contains(('anything', 'else'))": False,
#   "contains(('aopen', 'creative'))": False,
#   "contains(('apc', 'cisco'))": False,
#   "contains(('canada', 'u'))": False,
#   "contains(('canon', 'intellinet'))": False,
#   "contains(('change', 'usa'))": False,
#   "contains(('cisco', 'us'))": False,
#   "contains(('clearance', 'sale'))": False,
#   "contains(('com', 'compaq'))": False,
#   "contains(('compaq', 'hewlett'))": False,
#   "contains(('counterparty', 'meter'))": False,
#   "contains(('creative', 'toshiba'))": False,
#   "contains(('dell', 'intel'))": False,
#   "contains(('distributorjebel', 'ali'))": False,
#   "contains(('doc', 'Subject'))": False,
#   "contains(('due', 'diligence'))": False,
#   "contains(('epson', 'aopen'))": False,
#   "contains(('gary', 'w'))": False,
#   "contains(('hewlett', 'packard'))": False,
#   "contains(('hpl', 'meter'))": False,
#   "contains(('ibm', 'sony'))": False,
#   "contains(('intel', 'iomega'))": False,
#   "contains(('intellinet', 'targus'))": False,
#   "contains(('iomega', 'epson'))": False,
#   "contains(('latest', 'clearance'))": False,
#   "contains(('listing', 'contact'))": False,
#   "contains(('microsoft', 'canon'))": False,
#   "contains(('please', 'provide'))": False,
#   "contains(('robotics', 'microsoft'))": False,
#   "contains(('sale', 'listing'))": False,
#   "contains(('sally', 'beck'))": False,
#   "contains(('sheri', 'thomas'))": False,
#   "contains(('sitara', 'ticket'))": True,
#   "contains(('steve', 'venturatos'))": False,
#   "contains(('stop', 'distributorjebel'))": False,
#   "contains(('suggestions', 'contact'))": False,
#   "contains(('targus', 'viewsonic'))": False,
#   "contains(('teco', 'tap'))": False,
#   "contains(('toshiba', 'apc'))": False,
#   "contains(('us', 'robotics'))": False,
#   "contains(('viewsonic', 'ibm'))": False,
#   "contains(('w', 'lamphier'))": False,
#   "contains(('william', 'e'))": False,
#   "contains(('zone', 'www'))": False,
#   "contains(('carlos', 'j'))": False,
#   "contains(('com', 'tel'))": False,
#   "contains(('contact', 'via'))": False,
#   "contains(('david', 'baumbach'))": False,
#   "contains(('details', 'please'))": False,
#   "contains(('fontfont', 'color'))": False,
#   "contains(('graphics', 'suite'))": False,
#   "contains(('j', 'rodriguez'))": False,
#   "contains(('megan', 'parker'))": False,
#   "contains(('michael', 'eiben'))": False,
#   "contains(('past', 'performance'))": False,
#   "contains(('please', 'read'))": False,
#   "contains(('respective', 'owners'))": False,
#   "contains(('via', 'www'))": False,
#   "contains(('web', 'site'))": False,
#   "contains(('xp', 'pro'))": False,
#   "contains(('accounting', 'arrangement'))": False,
#   "contains(('accounting', 'arrangements'))": False,
#   "contains(('com', 'subject'))": False,
#   "contains(('counterparty', 'name'))": False,
#   "contains(('east', 'texas'))": False,
#   "contains(('flowed', 'w'))": False,
#   "contains(('force', 'majeure'))": False,
#   "contains(('heidi', 'withers'))": False,
#   "contains(('htmlimg', 'src'))": False,
#   "contains(('international', 'calls'))": False,
#   "contains(('james', 'mckay'))": False,
#   "contains(('last', 'flowed'))": False,
#   "contains(('material', 'within'))": False,
#   "contains(('ranch', 'nom'))": False,
#   "contains(('removed', 'Subject'))": False,
#   "contains(('td', 'align'))": False,
#   "contains(('transport', 'contract'))": False,
#   "contains(('transport', 'usage'))": False,
#   "contains(('actual', 'results'))": False,
#   "contains(('aeor', 'contact'))": False,
#   "contains(('buyback', 'ticket'))": False,
#   "contains(('el', 'sordo'))": False,
#   "contains(('free', 'zonedubai'))": False,
#   "contains(('g', 'connevey'))": False,
#   "contains(('kathryn', 'cordes'))": False,
#   "contains(('mobil', 'beaumont'))": False,
#   "contains(('owners', 'products'))": False,
#   "contains(('please', 'forward'))": False,
#   "contains(('report', 'list'))": False,
#   "contains(('super', 'viagra'))": False,
#   "contains(('yvette', 'g'))": False,
#   "contains(('bryce', 'baxter'))": False,
#   "contains(('dave', 'nommensen'))": False,
#   "contains(('exchange', 'act'))": False,
#   "contains(('get', 'back'))": False,
#   "contains(('hi', 'paliourg'))": False,
#   "contains(('hpl', 'nom'))": False,
#   "contains(('investment', 'advisor'))": False,
#   "contains(('kristin', 'albrecht'))": False,
#   "contains(('limited', 'time'))": False,
#   "contains(('mtbe', 'plant'))": False,
#   "contains(('path', 'manager'))": False,
#   "contains(('please', 'review'))": False,
#   "contains(('prescription', 'drugs'))": False,
#   "contains(('securities', 'exchange'))": False,
#   "contains(('statements', 'within'))": False,
#   "contains(('target', 'price'))": False,
#   "contains(('thanks', 'Subject'))": False,
#   "contains(('thanks', 'gary'))": False,
#   "contains(('us', 'know'))": False,
#   "contains(('application', 'report'))": False,
#   "contains(('back', 'guarantee'))": False,
#   "contains(('connor', 'meters'))": False,
#   "contains(('draw', 'graphics'))": False,
#   "contains(('enron', 'corp'))": False,
#   "contains(('exxon', 'clear'))": False,
#   "contains(('im', 'texas'))": False,
#   "contains(('img', 'border'))": False,
#   "contains(('line', 'gain'))": False,
#   "contains(('look', 'forward'))": False,
#   "contains(('next', 'month'))": False,
#   "contains(('please', 'check'))": False,
#   "contains(('please', 'fill'))": False,
#   "contains(('questions', 'please'))": False,
#   "contains(('security', 'company'))": False,
#   "contains(('soft', 'tabs'))": False,
#   "contains(('thanks', 'thu'))": False,
#   "contains(('three', 'rivers'))": False,
#   "contains(('transportation', 'contract'))": False,
#   "contains(('adobe', 'illustrator'))": False,
#   "contains(('brian', 'heinrich'))": False,
#   "contains(('business', 'development'))": False,
#   "contains(('energy', 'us'))": False,
#   "contains(('engage', 'energy'))": False,
#   "contains(('every', 'month'))": False,
#   "contains(('flash', 'mx'))": False,
#   "contains(('gas', 'company'))": False,
#   "contains(('gift', 'certificates'))": False,
#   "contains(('htmlimg', 'height'))": False,
#   "contains(('information', 'contained'))": False,
#   "contains(('information', 'within'))": False,
#   "contains(('katherine', 'l'))": False,
#   "contains(('l', 'kelly'))": False,
#   "contains(('motor', 'speedway'))": False,
#   "contains(('natural', 'adipren'))": False,
#   "contains(('press', 'releases'))": False,
#   "contains(('r', 'e'))": False,
#   "contains(('sale', 'ticket'))": False,
#   "contains(('states', 'dollars'))": False,
#   "contains(('strangers', 'gas'))": False,
#   "contains(('susan', 'harrison'))": False,
#   "contains(('tape', 'drive'))": False,
#   "contains(('afloat', 'conversion'))": False,
#   "contains(('appall', 'proletariat'))": False,
#   "contains(('b', 'cousino'))": False,
#   "contains(('biosphere', 'process'))": False,
#   "contains(('bleed', 'happenstance'))": False,
#   "contains(('boatload', 'defensive'))": False,
#   "contains(('calling', 'settlements'))": False,
#   "contains(('calpine', 'daily'))": False,
#   "contains(('canaan', 'appall'))": False,
#   "contains(('cause', 'actual'))": False,
#   "contains(('chad', 'w'))": False,
#   "contains(('cheryl', 'dudley'))": False,
#   "contains(('compendia', 'myrrh'))": False,
#   "contains(('conversion', 'dosage'))": False,
#   "contains(('cottonwood', 'quasar'))": False,
#   "contains(('current', 'price'))": False,
#   "contains(('daily', 'gas'))": False,
#   "contains(('darial', 'size'))": False,
#   "contains(('defensive', 'cottonwood'))": False,
#   "contains(('dosage', 'respecter'))": False,
#   "contains(('e', 'moscoso'))": False,
#   "contains(('ena', 'sales'))": False,
#   "contains(('expatriate', 'zone'))": False,
#   "contains(('featured', 'within'))": False,
#   "contains(('free', 'email'))": False,
#   "contains(('future', 'events'))": False,
#   "contains(('george', 'smith'))": False,
#   "contains(('happenstance', 'influential'))": False,
#   "contains(('htm', 'Subject'))": False,
#   "contains(('influential', 'kenton'))": False,
#   "contains(('kcs', 'energy'))": False,
#   "contains(('kenton', 'boatload'))": False,
#   "contains(('kevin', 'mclarney'))": False,
#   "contains(('limited', 'quantities'))": False,
#   "contains(('lisa', 'b'))": False,
#   "contains(('lst', 'rev'))": False,
#   "contains(('mailing', 'list'))": False,
#   "contains(('metabole', 'saloonkeep'))": False,
#   "contains(('michael', 'e'))": False,
#   "contains(('middle', 'width'))": False,
#   "contains(('myrrh', 'stock'))": False,
#   "contains(('nascar', 'silicon'))": False,
#   "contains(('nitrate', 'demagnify'))": False,
#   "contains(('panenergy', 'marketing'))": False,
#   "contains(('personal', 'research'))": False,
#   "contains(('please', 'visit'))": False,
#   "contains(('prc', 'meeting'))": False,
#   "contains(('press', 'release'))": False,
#   "contains(('proletariat', 'metabole'))": False,
#   "contains(('provided', 'within'))": False,
#   "contains(('quantities', 'available'))": False,
#   "contains(('quasar', 'canaan'))": False,
#   "contains(('respecter', 'compendia'))": False,
#   "contains(('saloonkeep', 'nitrate'))": False,
#   "contains(('san', 'felipe'))": False,
#   "contains(('scott', 'pleus'))": False,
#   "contains(('securities', 'must'))": False,
#   "contains(('securities', 'representative'))": False,
#   "contains(('seek', 'advice'))": False,
#   "contains(('selected', 'specials'))": False,
#   "contains(('silicon', 'motor'))": False,
#   "contains(('stock', 'bleed'))": False,
#   "contains(('stocks', 'featured'))": False,
#   "contains(('texas', 'desk'))": False,
#   "contains(('texas', 'gas'))": False,
#   "contains(('two', 'days'))": False,
#   "contains(('united', 'development'))": False,
#   "contains(('wellhead', 'portfolio'))": False,
#   "contains(('world', 'trade'))": False,
#   "contains(('ami', 'Subject'))": False,
#   "contains(('anger', 'scrap'))": False,
#   "contains(('bamako', 'cryptogram'))": False,
#   "contains(('baseboard', 'buoy'))": False,
#   "contains(('belize', 'city'))": False,
#   "contains(('bender', 'perforate'))": False,
#   "contains(('brand', 'new'))": False,
#   "contains(('bronco', 'chalcocite'))": False,
#   "contains(('buoy', 'unchristian'))": False,
#   "contains(('center', 'bgcolor'))": False,
#   "contains(('center', 'table'))": False,
#   "contains(('chalcocite', 'dupe'))": False,
#   "contains(('choral', 'chummy'))": False,
#   "contains(('chummy', 'thruway'))": False,
#   "contains(('cloudburst', 'needham'))": False,
#   "contains(('cognitive', 'rascal'))": False,
#   "contains(('cryptogram', 'enfant'))": False,
#   "contains(('curricular', 'bamako'))": False,
#   "contains(('demagnify', 'gallantry'))": False,
#   "contains(('div', 'div'))": False,
#   "contains(('donna', 'consemiu'))": False,
#   "contains(('dovekie', 'platelet'))": False,
#   "contains(('dreyfuss', 'prosaic'))": False,
#   "contains(('dupe', 'dreyfuss'))": False,
#   "contains(('e', 'texas'))": False,
#   "contains(('ffffffstrongfont', 'color'))": False,
#   "contains(('fred', 'Subject'))": False,
#   "contains(('gallantry', 'onlook'))": False,
#   "contains(('gas', 'allocated'))": False,
#   "contains(('gas', 'corporation'))": False,
#   "contains(('gas', 'flow'))": False,
#   "contains(('gas', 'processing'))": False,
#   "contains(('gas', 'services'))": False,
#   "contains(('gb', 'tape'))": False,
#   "contains(('global', 'due'))": False,
#   "contains(('hundred', 'thousand'))": False,
#   "contains(('interest', 'resulting'))": False,
#   "contains(('jennifer', 'reside'))": False,
#   "contains(('lisa', 'hesse'))": False,
#   "contains(('looks', 'like'))": False,
#   "contains(('ls', 'hpl'))": False,
#   "contains(('michael', 'r'))": False,
#   "contains(('million', 'email'))": False,
#   "contains(('needham', 'cognitive'))": False,
#   "contains(('next', 'day'))": False,
#   "contains(('onlook', 'wink'))": False,
#   "contains(('penis', 'enlargement'))": False,
#   "contains(('perforate', 'bronco'))": False,
#   "contains(('platelet', 'without'))": False,
#   "contains(('please', 'use'))": False,
#   "contains(('professional', 'securities'))": False,
#   "contains(('prosaic', 'vandenberg'))": False,
#   "contains(('rascal', 'curricular'))": False,
#   "contains(('registered', 'investment'))": False,
#   "contains(('registered', 'professional'))": False,
#   "contains(('reliant', 'energy'))": False,
#   "contains(('scrap', 'baseboard'))": False,
#   "contains(('sexual', 'health'))": False,
#   "contains(('sheila', 'glover'))": False,
#   "contains(('texas', 'nom'))": False,
#   "contains(('th', 'noms'))": False,
#   "contains(('thomas', 'engel'))": False,
#   "contains(('thruway', 'wilson'))": False,
#   "contains(('torch', 'rally'))": False,
#   "contains(('unchristian', 'bender'))": False,
#   "contains(('vandenberg', 'cloudburst'))": False,
#   "contains(('vice', 'president'))": False,
#   "contains(('vt', 'anger'))": False,
#   "contains(('wilson', 'vt'))": False,
#   "contains(('wink', 'dovekie'))": False,
#   "contains(('without', 'choral'))": False,
#   "contains(('acquisitive', 'invidious'))": False,
#   "contains(('alone', 'ambulate'))": False,
#   "contains(('ambulate', 'hayward'))": False,
#   "contains(('amorous', 'swamp'))": False,
#   "contains(('apace', 'sacrifice'))": False,
#   "contains(('azimuthal', 'profound'))": False,
#   "contains(('banister', 'tampon'))": False,
#   "contains(('batchelder', 'irremovable'))": False,
#   "contains(('beman', 'fund'))": False,
#   "contains(('benefit', 'continuo'))": False,
#   "contains(('biochemic', 'legacy'))": False,
#   "contains(('biota', 'horoscope'))": False,
#   "contains(('bramble', 'poem'))": False,
#   "contains(('brendan', 'edmund'))": False,
#   "contains(('bridegroom', 'stipulate'))": False,
#   "contains(('broomcorn', 'kinesic'))": False,
#   "contains(('burdock', 'case'))": False,
#   "contains(('buzzing', 'burdock'))": False,
#   "contains(('calculable', 'godparent'))": False,
#   "contains(('calgary', 'clobber'))": False,
#   "contains(('canopy', 'cyclist'))": False,
#   "contains(('case', 'degradation'))": False,
#   "contains(('catherine', 'emma'))": False,
#   "contains(('chandelier', 'procedure'))": False,
#   "contains(('charybdis', 'controller'))": False,
#   "contains(('clobber', 'yokel'))": False,
#   "contains(('cochrane', 'calculable'))": False,
#   "contains(('cockcrow', 'azimuthal'))": False,
#   "contains(('committeemen', 'shove'))": False,
#   "contains(('confrere', 'crankcase'))": False,
#   "contains(('confront', 'huntley'))": False,
#   "contains(('congratulate', 'extravaganza'))": False,
#   "contains(('connie', 'sutton'))": False,
#   "contains(('continuo', 'mig'))": False,
#   "contains(('controller', 'gatekeep'))": False,
#   "contains(('copano', 'line'))": False,
#   "contains(('cradle', 'bramble'))": False,
#   "contains(('crania', 'pluperfect'))": False,
#   "contains(('crankcase', 'polymerase'))": False,
#   "contains(('credential', 'biota'))": False,
#   "contains(('crib', 'silver'))": False,
#   "contains(('cyclist', 'batchelder'))": False,
#   "contains(('dana', 'daigle'))": False,
#   "contains(('dang', 'denture'))": False,
#   "contains(('darpa', 'charybdis'))": False,
#   "contains(('dashboard', 'catherine'))": False,
#   "contains(('dba', 'garrison'))": False,
#   "contains(('deal', 'validation'))": False,
#   "contains(('debacle', 'mesmeric'))": False,
#   "contains(('debug', 'cockcrow'))": False,
#   "contains(('degeneracy', 'cradle'))": False,
#   "contains(('degradation', 'explore'))": False,
#   "contains(('dent', 'massey'))": False,
#   "contains(('denture', 'confrere'))": False,
#   "contains(('development', 'international'))": False,
#   "contains(('donna', 'greif'))": False,
#   "contains(('dosage', 'afloat'))": False,
#   "contains(('durrell', 'beman'))": False,
#   "contains(('earthquake', 'twit'))": False,
#   "contains(('edit', 'superb'))": False,
#   "contains(('edmund', 'togs'))": False,
#   "contains(('edward', 'terry'))": False,
#   "contains(('el', 'paso'))": False,
#   "contains(('embargoes', 'thelma'))": False,
#   "contains(('emma', 'apace'))": False,
#   "contains(('emotional', 'debacle'))": False,
#   "contains(('enron', 'actuals'))": False,
#   "contains(('enron', 'methanol'))": False,
#   "contains(('euridyce', 'yea'))": False,
#   "contains(('explore', 'startle'))": False,
#   "contains(('extravaganza', 'loudspeaker'))": False,
#   "contains(('female', 'degeneracy'))": False,
#   "contains(('five', 'hundred'))": False,
#   "contains(('fletcher', 'durrell'))": False,
#   "contains(('fontfont', 'face'))": False,
#   "contains(('fund', 'novelty'))": False,
#   "contains(('future', 'results'))": False,
#   "contains(('gap', 'gift'))": False,
#   "contains(('gas', 'loss'))": False,
#   "contains(('gas', 'pipeline'))": False,
#   "contains(('gatekeep', 'nave'))": False,
#   "contains(('gecko', 'triple'))": False,
#   "contains(('gif', 'border'))": False,
#   "contains(('godparent', 'embargoes'))": False,
#   "contains(('green', 'fee'))": False,
#   "contains(('hayward', 'redhead'))": False,
#   "contains(('hendricks', 'persistent'))": False,
#   "contains(('heretofore', 'pop'))": False,
#   "contains(('high', 'quality'))": False,
#   "contains(('horoscope', 'banister'))": False,
#   "contains(('hplr', 'liquids'))": False,
#   "contains(('humble', 'lieutenant'))": False,
#   "contains(('huntley', 'cochrane'))": False,
#   "contains(('img', 'height'))": False,
#   "contains(('instant', 'steppe'))": False,
#   "contains(('integrate', 'debug'))": False,
#   "contains(('invidious', 'bridegroom'))": False,
#   "contains(('invitation', 'prior'))": False,
#   "contains(('irremovable', 'calgary'))": False,
#   "contains(('j', 'hanson'))": False,
#   "contains(('kinesic', 'acquisitive'))": False,
#   "contains(('kristen', 'j'))": False,
#   "contains(('l', 'gay'))": False,
#   "contains(('las', 'vegas'))": False,
#   "contains(('legacy', 'polemic'))": False,
#   "contains(('lieutenant', 'fletcher'))": False,
#   "contains(('lone', 'star'))": False,
#   "contains(('lose', 'weight'))": False,
#   "contains(('loudspeaker', 'pilewort'))": False,
#   "contains(('mail', 'invitation'))": False,
#   "contains(('management', 'team'))": False,
#   "contains(('massey', 'buzzing'))": False,
#   "contains(('may', 'need'))": False,
#   "contains(('may', 'want'))": False,
#   "contains(('mesmeric', 'amorous'))": False,
#   "contains(('methanol', 'plant'))": False,
#   "contains(('midcon', 'invoices'))": False,
#   "contains(('must', 'present'))": False,
#   "contains(('nave', 'roster'))": False,
#   "contains(('new', 'deals'))": False,
#   "contains(('news', 'release'))": False,
#   "contains(('norton', 'antivirus'))": False,
#   "contains(('novelty', 'crania'))": False,
#   "contains(('osborn', 'dang'))": False,
#   "contains(('p', 'schwarz'))": False,
#   "contains(('pec', 'subject'))": False,
#   "contains(('peggy', 'hedstrom'))": False,
#   "contains(('persistent', 'dashboard'))": False,
#   "contains(('please', 'extend'))": False,
#   "contains(('pluperfect', 'prick'))": False,
#   "contains(('poem', 'theta'))": False,
#   "contains(('polemic', 'cavern'))": False,
#   "contains(('polymerase', 'sprang'))": False,
#   "contains(('pop', 'abhorred'))": False,
#   "contains(('present', 'e'))": False,
#   "contains(('prick', 'furnace'))": False,
#   "contains(('procedure', 'darpa'))": False,
#   "contains(('profound', 'crib'))": False,
#   "contains(('quirt', 'confront'))": False,
#   "contains(('randall', 'l'))": False,
#   "contains(('redhead', 'stumpage'))": False,
#   "contains(('rev', 'mar'))": False,
#   "contains(('sacrifice', 'conciliatory'))": False,
#   "contains(('serial', 'number'))": False,
#   "contains(('shove', 'zeroes'))": False,
#   "contains(('silver', 'congratulate'))": False,
#   "contains(('sitara', 'based'))": False,
#   "contains(('sprang', 'chandelier'))": False,
#   "contains(('sri', 'osborn'))": False,
#   "contains(('startle', 'humble'))": False,
#   "contains(('statesmen', 'credential'))": False,
#   "contains(('stephanie', 'sever'))": False,
#   "contains(('stephen', 'p'))": False,
#   "contains(('steppe', 'gecko'))": False,
#   "contains(('stipulate', 'earthquake'))": False,
#   "contains(('stumpage', 'instant'))": False,
#   "contains(('superb', 'biochemic'))": False,
#   "contains(('swamp', 'quirt'))": False,
#   "contains(('tampon', 'edit'))": False,
#   "contains(('td', 'height'))": False,
#   "contains(('thelma', 'thought'))": False,
#   "contains(('theta', 'benefit'))": False,
#   "contains(('todd', 'hall'))": False,
#   "contains(('togs', 'heretofore'))": False,
#   "contains(('tonk', 'canopy'))": False,
#   "contains(('track', 'id'))": False,
#   "contains(('triple', 'washbowl'))": False,
#   "contains(('twit', 'brendan'))": False,
#   "contains(('usage', 'tickets'))": False,
#   "contains(('user', 'id'))": False,
#   "contains(('vera', 'committeemen'))": False,
#   "contains(('washbowl', 'tonk'))": False,
#   "contains(('wifi', 'refurb'))": False,
#   "contains(('would', 'need'))": False,
#   "contains(('yea', 'broomcorn'))": False,
#   "contains(('yokel', 'female'))": False,
#   "contains(('zeroes', 'hendricks'))": False,
#   "contains(('action', 'may'))": False,
#   "contains(('aimee', 'Subject'))": False,
#   "contains(('brand', 'name'))": False,
#   "contains(('brandywine', 'meter'))": False,
#   "contains(('brenda', 'herod'))": False,
#   "contains(('china', 'world'))": False,
#   "contains(('clem', 'cernosek'))": False,
#   "contains(('contains', 'forward'))": False,
#   "contains(('contract', 'needed'))": False,
#   "contains(('could', 'get'))": False,
#   "contains(('cynthia', 'hakemack'))": False,
#   "contains(('delivery', 'meter'))": False,
#   "contains(('elizabeth', 'l'))": False,
#   "contains(('enron', 'Subject'))": False,
#   "contains(('faye', 'ellis'))": False,
#   "contains(('fda', 'approved'))": False,
#   "contains(('following', 'changes'))": False,
#   "contains(('following', 'information'))": False,
#   "contains(('free', 'shipping'))": False,
#   "contains(('future', 'looking'))": False,
#   "contains(('gain', 'contract'))": False,
#   "contains(('h', 'ngo'))": False,
#   "contains(('heather', 'choate'))": False,
#   "contains(('hpl', 'nomination'))": False,
#   "contains(('hpl', 'noms'))": False,
#   "contains(('involve', 'discussions'))": False,
#   "contains(('joanie', 'h'))": False,
#   "contains(('ken', 'Subject'))": False,
#   "contains(('l', 'hernandez'))": False,
#   "contains(('lisa', 'cousino'))": False,
#   "contains(('nat', 'gas'))": False,
#   "contains(('offers', 'Subject'))": False,
#   "contains(('one', 'month'))": False,
#   "contains(('overnight', 'shipping'))": False,
#   "contains(('pat', 'Subject'))": False,
#   "contains(('per', 'month'))": False,
#   "contains(('per', 'player'))": False,
#   "contains(('presently', 'anticipated'))": False,
#   "contains(('production', 'estimate'))": False,
#   "contains(('report', 'shall'))": False,
#   "contains(('sitara', 'release'))": False,
#   "contains(('southern', 'union'))": False,
#   "contains(('southwest', 'gas'))": False,
#   "contains(('steve', 'jackson'))": False,
#   "contains(('take', 'advantage'))": False,
#   "contains(('thousand', 'dollars'))": False,
#   "contains(('thousand', 'united'))": False,
#   "contains(('time', 'offer'))": False,
#   "contains(('transport', 'contracts'))": False,
#   "contains(('yvette', 'x'))": False,
#   "contains(('adobe', 'pagemaker'))": False,
#   "contains(('atlantis', 'business'))": False,
#   "contains(('b', 'scott'))": False,
#   "contains(('bob', 'Subject'))": False,
#   "contains(('bridge', 'back'))": False,
#   "contains(('business', 'unit'))": False,
#   "contains(('cannon', 'interest'))": False,
#   "contains(('center', 'center'))": False,
#   "contains(('certain', 'actions'))": False,
#   "contains(('commercial', 'teams'))": False,
#   "contains(('company', 'press'))": False,
#   "contains(('current', 'month'))": False,
#   "contains(('dcenterfont', 'face'))": False,
#   "contains(('de', 'la'))": False,
#   "contains(('dianne', 'j'))": False,
#   "contains(('donna', 'c'))": False,
#   "contains(('e', 'r'))": False,
#   "contains(('e', 'texoma'))": False,
#   "contains(('eric', 'bass'))": False,
#   "contains(('eugenio', 'perez'))": False,
#   "contains(('ffffff', 'width'))": False,
#   "contains(('field', 'services'))": False,
#   "contains(('financial', 'services'))": False,
#   "contains(('going', 'concern'))": False,
#   "contains(('going', 'forward'))": False,
#   "contains(('gulf', 'energy'))": False,
#   "contains(('historical', 'fact'))": False,
#   "contains(('indicating', 'certain'))": False,
#   "contains(('instant', 'download'))": False,
#   "contains(('internet', 'protocol'))": False,
#   "contains(('j', 'swiber'))": False,
#   "contains(('j', 'yanowski'))": False,
#   "contains(('kingwood', 'cove'))": False,
#   "contains(('knox', 'westmoreland'))": False,
#   "contains(('mail', 'address'))": False,
#   "contains(('marketing', 'jackie'))": False,
#   "contains(('name', 'change'))": False,
#   "contains(('new', 'product'))": False,
#   "contains(('new', 'sitara'))": False,
#   "contains(('organizational', 'changes'))": False,
#   "contains(('php', 'Subject'))": False,
#   "contains(('please', 'create'))": False,
#   "contains(('please', 'keep'))": False,
#   "contains(('please', 'update'))": False,
#   "contains(('prescription', 'needed'))": False,
#   "contains(('rc', 'report'))": False,
#   "contains(('revised', 'nomination'))": False,
#   "contains(('risk', 'factors'))": False,
#   "contains(('robert', 'cotten'))": False,
#   "contains(('santa', 'monica'))": False,
#   "contains(('scott', 'palmer'))": False,
#   "contains(('sec', 'filings'))": False,
#   "contains(('set', 'forth'))": False,
#   "contains(('south', 'africa'))": False,
#   "contains(('statements', 'indicating'))": False,
#   "contains(('teco', 'gas'))": False,
#   "contains(('texas', 'city'))": False,
#   "contains(('texas', 'utilities'))": False,
#   "contains(('texoma', 'volumes'))": False,
#   "contains(('tommy', 'j'))": False,
#   "contains(('transport', 'imbalance'))": False,
#   "contains(('union', 'gas'))": False,
#   "contains(('unmetered', 'gas'))": False,
#   "contains(('valid', 'deal'))": False,
#   "contains(('well', 'head'))": False,
#   "contains(('windows', 'server'))": False,
#   "contains(('actions', 'may'))": False,
#   "contains(('anyone', 'aged'))": False,
#   "contains(('bractive', 'within'))": False,
#   "contains(('cartwheel', 'agreement'))": False,
#   "contains(('committed', 'reserves'))": False,
#   "contains(('correct', 'transportation'))": False,
#   "contains(('darialfont', 'color'))": False,
#   "contains(('de', 'l'))": False,
#   "contains(('desk', 'deals'))": False,
#   "contains(('development', 'corporation'))": False,
#   "contains(('email', 'contains'))": False,
#   "contains(('energy', 'services'))": False,
#   "contains(('enron', 'capital'))": False,
#   "contains(('entire', 'month'))": False,
#   "contains(('every', 'day'))": False,
#   "contains(('featured', 'company'))": False,
#   "contains(('female', 'seeks'))": False,
#   "contains(('first', 'delivery'))": False,
#   "contains(('font', 'size'))": False,
#   "contains(('gary', 'h'))": False,
#   "contains(('gif', 'height'))": False,
#   "contains(('good', 'luck'))": False,
#   "contains(('hours', 'brrating'))": False,
#   "contains(('iferc', 'texoma'))": False,
#   "contains(('im', 'wellhead'))": False,
#   "contains(('imelda', 'frayre'))": False,
#   "contains(('information', 'herein'))": False,
#   "contains(('k', 'sitara'))": False,
#   "contains(('katherine', 'herrera'))": False,
#   "contains(('left', 'font'))": False,
#   "contains(('lefta', 'href'))": False,
#   "contains(('leslie', 'reeves'))": False,
#   "contains(('light', 'company'))": False,
#   "contains(('like', 'tier'))": False,
#   "contains(('long', 'term'))": False,
#   "contains(('many', 'people'))": False,
#   "contains(('meter', 'volumes'))": False,
#   "contains(('might', 'occur'))": False,
#   "contains(('need', 'anything'))": False,
#   "contains(('new', 'buyback'))": False,
#   "contains(('new', 'generation'))": False,
#   "contains(('new', 'sale'))": False,
#   "contains(('new', 'year'))": False,
#   "contains(('pipe', 'line'))": False,
#   "contains(('please', 'notify'))": False,
#   "contains(('popular', 'meds'))": False,
#   "contains(('powerful', 'weightloss'))": False,
#   "contains(('prior', 'prescription'))": False,
#   "contains(('px', 'solid'))": False,
#   "contains(('questions', 'regarding'))": False,
#   "contains(('revised', 'availability'))": False,
#   "contains(('seeks', 'anyone'))": False,
#   "contains(('settlements', 'asking'))": False,
#   "contains(('span', 'class'))": False,
#   "contains(('steve', 'schneider'))": False,
#   "contains(('table', 'bgcolor'))": False,
#   "contains(('table', 'table'))": False,
#   "contains(('take', 'place'))": False,
#   "contains(('td', 'style'))": False,
#   "contains(('thu', 'Subject'))": False,
#   "contains(('ticket', 'set'))": False,
#   "contains(('top', 'align'))": False,
#   "contains(('top', 'width'))": False,
#   "contains(('trade', 'corp'))": False,
#   "contains(('visual', 'studio'))": False,
#   "contains(('volume', 'price'))": False,
#   "contains(('volumes', 'price'))": False,
#   "contains(('wholly', 'owned'))": False,
#   "contains(('without', 'bias'))": False,
#   "contains(('without', 'exercise'))": False,
#   "contains(('affiliate', 'shareholder'))": False,
#   "contains(('agenda', 'recap'))": False,
#   "contains(('also', 'available'))": False,
#   "contains(('another', 'deal'))": False,
#   "contains(('apple', 'investments'))": False,
#   "contains(('belize', 'Subject'))": False,
#   "contains(('bob', 'klein'))": False,
#   "contains(('brian', 'redmond'))": False,
#   "contains(('cap', 'stocks'))": False,
#   "contains(('change', 'counterparties'))": False,
#   "contains(('comic', 'sans'))": False,
#   "contains(('company', 'websites'))": False,
#   "contains(('compensation', 'due'))": False,
#   "contains(('competitive', 'rates'))": False,
#   "contains(('confirmed', 'volumes'))": False,
#   "contains(('congratulatory', 'salaam'))": False,
#   "contains(('contract', 'type'))": False,
#   "contains(('cousino', 'x'))": False,
#   "contains(('credit', 'card'))": False,
#   "contains(('cross', 'media'))": False,
#   "contains(('dow', 'meter'))": False,
#   "contains(('dreamwaver', 'mx'))": False,
#   "contains(('earl', 'tisdale'))": False,
#   "contains(('eastrans', 'redeliveries'))": False,
#   "contains(('eex', 'corporation'))": False,
#   "contains(('evergreen', 'flag'))": False,
#   "contains(('fact', 'necessary'))": False,
#   "contains(('feb', 'midcon'))": False,
#   "contains(('field', 'contact'))": False,
#   "contains(('financial', 'operations'))": False,
#   "contains(('firm', 'ticket'))": False,
#   "contains(('flatulent', 'statesmen'))": False,
#   "contains(('gary', 'Subject'))": False,
#   "contains(('gas', 'transmission'))": False,
#   "contains(('generation', 'group'))": False,
#   "contains(('generic', 'viagra'))": False,
#   "contains(('george', 'x'))": False,
#   "contains(('give', 'us'))": False,
#   "contains(('h', 'wallis'))": False,
#   "contains(('hard', 'work'))": False,
#   "contains(('head', 'body'))": False,
#   "contains(('hector', 'mcloughlin'))": False,
#   "contains(('hpl', 'delivery'))": False,
#   "contains(('janet', 'h'))": False,
#   "contains(('karie', 'hastings'))": False,
#   "contains(('last', 'much'))": False,
#   "contains(('left', 'unpathed'))": False,
#   "contains(('lisa', 'kinsey'))": False,
#   "contains(('low', 'rates'))": False,
#   "contains(('macromedia', 'flash'))": False,
#   "contains(('madras', 'meson'))": False,
#   "contains(('many', 'many'))": False,
#   "contains(('mark', 'friedman'))": False,
#   "contains(('meeting', 'agenda'))": False,
#   "contains(('meson', 'mitosis'))": False,
#   "contains(('message', 'states'))": False,
#   "contains(('meter', 'volume'))": False,
#   "contains(('meters', 'daren'))": False,
#   "contains(('mitosis', 'quadrant'))": False,
#   "contains(('muscle', 'relaxants'))": False,
#   "contains(('n', 'plus'))": False,
#   "contains(('name', 'changes'))": False,
#   "contains(('nathaniel', 'energy'))": False,
#   "contains(('need', 'perfect'))": False,
#   "contains(('oasis', 'katy'))": False,
#   "contains(('per', 'dose'))": False,
#   "contains(('perfect', 'timing'))": False,
#   "contains(('photoshop', 'cs'))": False,
#   "contains(('please', 'join'))": False,
#   "contains(('please', 'verify'))": False,
#   "contains(('price', 'period'))": False,
#   "contains(('processing', 'company'))": False,
#   "contains(('quadrant', 'congratulatory'))": False,
#   "contains(('rate', 'design'))": False,
#   "contains(('real', 'estate'))": False,
#   "contains(('referenced', 'based'))": False,
#   "contains(('revision', 'effective'))": False,
#   "contains(('rhonda', 'robinson'))": False,
#   "contains(('richard', 'burchfield'))": False,
#   "contains(('robin', 'p'))": False,
#   "contains(('salaam', 'transferred'))": False,
#   "contains(('save', 'money'))": False,
#   "contains(('server', 'windows'))": False,
#   "contains(('shares', 'outstanding'))": False,
#   "contains(('south', 'america'))": False,
#   "contains(('statements', 'therein'))": False,
#   "contains(('stock', 'report'))": False,
#   "contains(('table', 'border'))": False,
#   "contains(('texas', 'pipeline'))": False,
#   "contains(('thanks', 'ken'))": False,
#   "contains(('thorough', 'due'))": False,
#   "contains(('top', 'quality'))": False,
#   "contains(('transferred', 'flatulent'))": False,
#   "contains(('two', 'deals'))": False,
#   "contains(('view', 'information'))": False,
#   "contains(('wireless', 'router'))": False,
#   "contains(('without', 'prescription'))": False,
#   "contains(('xp', 'home'))": False,
#   "contains(('abdominal', 'fat'))": False,
#   "contains(('add', 'atleast'))": False,
#   "contains(('allow', 'us'))": False,
#   "contains(('altra', 'gms'))": False,
#   "contains(('anyone', 'else'))": False,
#   "contains(('available', 'without'))": False,
#   "contains(('becky', 'pitre'))": False,
#   "contains(('beginning', 'next'))": False,
#   "contains(('biz', 'best'))": False,
#   "contains(('black', 'marlin'))": False,
#   "contains(('body', 'weight'))": False,
#   "contains(('bulk', 'email'))": False,
#   "contains(('burns', 'calorized'))": False,
#   "contains(('calorized', 'fat'))": False,
#   "contains(('ces', 'deals'))": False,
#   "contains(('cheap', 'prices'))": False,
#   "contains(('clay', 'deaton'))": False,
#   "contains(('close', 'schedule'))": False,
#   "contains(('com', 'address'))": False,
#   "contains(('commercial', 'team'))": False,
#   "contains(('company', 'inc'))": False,
#   "contains(('completed', 'prior'))": False,
#   "contains(('confidence', 'level'))": False,
#   "contains(('contact', 'us'))": False,
#   "contains(('corpus', 'christi'))": False,
#   "contains(('cove', 'golf'))": False,
#   "contains(('customer', 'service'))": False,
#   "contains(('data', 'quality'))": False,
#   "contains(('day', 'friday'))": False,
#   "contains(('day', 'shlpp'))": False,
#   "contains(('days', 'ago'))": False,
#   "contains(('deal', 'numbers'))": False,
#   "contains(('dear', 'friend'))": False,
#   "contains(('dear', 'sir'))": False,
#   "contains(('deer', 'park'))": False,
#   "contains(('delta', 'mining'))": False,
#   "contains(('devon', 'energy'))": False,
#   "contains(('diligence', 'effort'))": False,
#   "contains(('e', 'seales'))": False,
#   "contains(('eagle', 'relaxation'))": False,
#   "contains(('email', 'pertaining'))": False,
#   "contains(('enron', 'net'))": False,
#   "contains(('even', 'though'))": False,
#   "contains(('external', 'bammel'))": False,
#   "contains(('fine', 'wein'))": False,
#   "contains(('front', 'door'))": False,
#   "contains(('future', 'mailings'))": False,
#   "contains(('gary', 'anderson'))": False,
#   "contains(('gas', 'day'))": False,
#   "contains(('gas', 'deliveries'))": False,
#   "contains(('genex', 'pharmaceutical'))": False,
#   "contains(('global', 'contracts'))": False,
#   "contains(('go', 'back'))": False,
#   "contains(('goes', 'live'))": False,
#   "contains(('growth', 'stock'))": False,
#   ...},
#  'ham')

# %%
#how we run the classifier to see if we get a good accuracy score
#all this is just to find out which feature is more informative to predict sentiment
#Naive Bayes classifier with 5-fold cross validation for training on sentiments using bigram features
start = time.time()
kf = KFold(n_splits = num_split)
sum = 0
prec = 0
recall = 0

for train, test in kf.split(featuresets2):
    train_data = np.array(featuresets2)[train]
    test_data = np.array(featuresets2)[test]
    classifier = nltk.NaiveBayesClassifier.train(train_data)
    sum += nltk.classify.accuracy(classifier, test_data)
    
    #calculating precision and recall 
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)

    for i, (feats, label) in enumerate(test_data):
        refsets[label].add(i)
        observed = classifier.classify(feats)
        testsets[observed].add(i)
    
    prec += nltk.precision(refsets['spam'], testsets['spam'])
    recall += nltk.recall(refsets['spam'], testsets['spam'])

#storing the score in a variable 
acc2 = sum/num_split
avg_precision2 = prec/num_split
avg_recall2 = recall/num_split

end = time.time()
print("Processing Time: {0:.2f} seconds".format(end - start))

#let's see the accuracy score for this new classifier
print("Accuracy:", round(acc2,4))
print("Precision:", round(avg_precision2,4))
print("Recall:", round(avg_recall2,4))
# Out:
# Processing Time: 30.12 seconds
# Accuracy: 0.93
# Precision: 0.8835
# Recall: 0.991

# %%
## EXPERIMENT 2 - REMOVE STOPWORDS AND CERTAIN PUNCTATION ##

all_words = [word for (email,category) in emaildocs for word in email]
nltkstopwords = nltk.corpus.stopwords.words('english')
punctuation = ['-', '.', '/', ',', ':', '@', '=', '?', "'", ')', '(', '_', ';', '*']
stopwords = nltkstopwords + punctuation
all_words_stopped = [w for w in all_words if not w in stopwords]
top_words = nltk.FreqDist(all_words_stopped)
most_common_words = top_words.most_common(2000)
word_features3 = [word for (word,count) in most_common_words]

#checking if we have the 2000 words we need
len(set(all_words_stopped))
# Out:
# 37097

# %%
word_features3[:20]
# Out:
# ['ect',
#  'hou',
#  'Subject',
#  '!',
#  '2000',
#  'enron',
#  '3',
#  '$',
#  'please',
#  '``',
#  '1',
#  'com',
#  '2',
#  'e',
#  '%',
#  '00',
#  '#',
#  '>',
#  'subject',
#  'meter']

# %%
#now we apply the function to the document dataset
featuresets3 = [(document_features(d, word_features3), c) for (d, c) in emaildocs]

#we print the list of features matches for the first document ([0]) in the corpus
#we'll see a Python dictionary with the key being the feature word
#and the value being 'True' or 'False' according to that word being matched in the present document or not
#we'll se a lot of 'False' values because (of course) not all 2000 words will be on each sentence!
featuresets3[0]
# Out:
# ({'contains(ect)': False,
#   'contains(hou)': False,
#   'contains(Subject)': True,
#   'contains(!)': False,
#   'contains(2000)': False,
#   'contains(enron)': False,
#   'contains(3)': False,
#   'contains($)': False,
#   'contains(please)': False,
#   'contains(``)': False,
#   'contains(1)': False,
#   'contains(com)': False,
#   'contains(2)': False,
#   'contains(e)': False,
#   'contains(%)': False,
#   'contains(00)': False,
#   'contains(#)': True,
#   'contains(>)': False,
#   'contains(subject)': False,
#   'contains(meter)': False,
#   'contains(pm)': False,
#   'contains(gas)': True,
#   'contains(cc)': False,
#   'contains(deal)': False,
#   'contains(0)': True,
#   'contains(http)': False,
#   'contains(99)': False,
#   'contains(000)': False,
#   'contains(corp)': False,
#   'contains(new)': False,
#   'contains(thanks)': False,
#   'contains(get)': False,
#   'contains(10)': False,
#   'contains(4)': False,
#   'contains(5)': False,
#   'contains(&)': False,
#   'contains(know)': False,
#   'contains(|)': False,
#   'contains(need)': False,
#   'contains(forwarded)': False,
#   'contains(03)': False,
#   'contains(12)': False,
#   'contains(p)': False,
#   'contains(may)': False,
#   'contains(daren)': False,
#   'contains(hpl)': False,
#   'contains(7)': False,
#   'contains(information)': False,
#   'contains(us)': False,
#   'contains(company)': False,
#   'contains(01)': False,
#   'contains(mmbtu)': False,
#   'contains(05)': False,
#   'contains(www)': False,
#   'contains(04)': False,
#   'contains(02)': False,
#   'contains(l)': False,
#   'contains(let)': False,
#   'contains(time)': False,
#   'contains(would)': False,
#   'contains(6)': False,
#   'contains(11)': False,
#   'contains(price)': False,
#   'contains(b)': False,
#   'contains(one)': True,
#   'contains(th)': False,
#   'contains(month)': False,
#   'contains(mail)': False,
#   'contains(contract)': False,
#   'contains(8)': False,
#   'contains(td)': False,
#   'contains(email)': False,
#   'contains(nbsp)': False,
#   'contains(sitara)': True,
#   'contains(see)': False,
#   'contains(20)': False,
#   'contains(j)': False,
#   'contains(])': False,
#   'contains([)': False,
#   'contains(day)': False,
#   'contains(x)': False,
#   'contains(also)': False,
#   'contains(15)': False,
#   'contains(volume)': False,
#   'contains(free)': False,
#   'contains(like)': False,
#   'contains(energy)': False,
#   'contains(c)': False,
#   'contains(deals)': False,
#   'contains(font)': False,
#   'contains(pills)': False,
#   'contains(change)': False,
#   'contains(ami)': False,
#   'contains(30)': False,
#   'contains(business)': False,
#   'contains(message)': False,
#   'contains(want)': False,
#   'contains(r)': False,
#   'contains(volumes)': False,
#   'contains(2004)': False,
#   'contains(attached)': False,
#   'contains(+)': False,
#   'contains(farmer)': False,
#   'contains(xls)': False,
#   'contains(09)': False,
#   'contains(questions)': False,
#   'contains(contact)': False,
#   'contains(9)': False,
#   'contains(make)': False,
#   'contains(width)': False,
#   'contains(report)': False,
#   'contains(25)': False,
#   'contains(60)': False,
#   'contains(call)': False,
#   'contains(06)': False,
#   'contains(list)': False,
#   'contains(click)': False,
#   'contains(back)': False,
#   'contains(money)': False,
#   'contains(f)': False,
#   'contains(100)': False,
#   'contains(texas)': False,
#   'contains(could)': False,
#   'contains(nom)': False,
#   'contains(set)': False,
#   'contains(chokshi)': False,
#   'contains(inc)': False,
#   'contains(robert)': False,
#   'contains(height)': False,
#   'contains(following)': False,
#   'contains(order)': False,
#   'contains(24)': False,
#   'contains(50)': False,
#   'contains(forward)': False,
#   'contains(production)': False,
#   'contains(08)': False,
#   'contains(w)': False,
#   'contains(january)': False,
#   'contains(21)': False,
#   'contains(per)': False,
#   'contains(today)': False,
#   'contains(statements)': False,
#   'contains(march)': False,
#   'contains(best)': False,
#   'contains(sale)': False,
#   'contains(ena)': False,
#   'contains(number)': False,
#   'contains(k)': False,
#   'contains(available)': False,
#   'contains(first)': False,
#   'contains(g)': False,
#   'contains(take)': True,
#   'contains(31)': False,
#   'contains(system)': False,
#   'contains(align)': False,
#   'contains(sent)': False,
#   'contains(go)': False,
#   'contains(days)': False,
#   'contains(help)': False,
#   'contains(management)': False,
#   'contains(98)': False,
#   'contains(stock)': False,
#   'contains(jackie)': False,
#   'contains(u)': False,
#   'contains(v)': False,
#   'contains(tr)': False,
#   'contains(online)': False,
#   'contains(23)': False,
#   'contains(ticket)': True,
#   'contains(changes)': False,
#   'contains(june)': False,
#   'contains(size)': False,
#   'contains(within)': False,
#   'contains(n)': False,
#   'contains(14)': False,
#   'contains(flow)': False,
#   'contains(border)': False,
#   'contains(info)': False,
#   'contains(last)': False,
#   'contains(18)': False,
#   'contains(nd)': False,
#   'contains(well)': False,
#   'contains(group)': False,
#   'contains(16)': False,
#   'contains(gary)': False,
#   'contains(address)': False,
#   'contains(service)': False,
#   'contains(next)': False,
#   'contains(team)': False,
#   'contains(transport)': False,
#   'contains(pec)': False,
#   'contains(effective)': False,
#   'contains(work)': False,
#   'contains(color)': False,
#   'contains(april)': False,
#   'contains(due)': False,
#   'contains(face)': False,
#   'contains(use)': False,
#   'contains(account)': False,
#   'contains(buy)': False,
#   'contains(sales)': False,
#   'contains(looking)': False,
#   'contains(69)': False,
#   'contains(22)': False,
#   'contains(nomination)': False,
#   'contains(many)': False,
#   'contains(office)': False,
#   'contains(without)': False,
#   'contains(offer)': False,
#   'contains(microsoft)': False,
#   "contains('')": False,
#   'contains(net)': False,
#   'contains(services)': False,
#   'contains(week)': False,
#   'contains(prices)': False,
#   'contains(name)': False,
#   'contains(63)': False,
#   'contains(year)': False,
#   'contains(19)': False,
#   'contains(feb)': False,
#   'contains(save)': False,
#   'contains(delivery)': False,
#   'contains(17)': False,
#   'contains(line)': False,
#   'contains(thank)': False,
#   'contains(link)': False,
#   'contains(send)': False,
#   'contains(aimee)': False,
#   'contains(special)': False,
#   'contains(13)': False,
#   'contains(date)': False,
#   'contains(desk)': False,
#   'contains(million)': False,
#   'contains(27)': False,
#   'contains(file)': False,
#   'contains(40)': False,
#   'contains(investment)': False,
#   'contains(href)': False,
#   'contains(src)': False,
#   'contains(products)': False,
#   'contains(90)': False,
#   'contains(made)': False,
#   'contains(br)': False,
#   'contains(pat)': False,
#   'contains(future)': False,
#   'contains(needs)': True,
#   'contains(software)': False,
#   'contains(161)': False,
#   'contains(two)': False,
#   'contains(give)': False,
#   'contains(steve)': False,
#   'contains(windows)': False,
#   'contains(meeting)': False,
#   'contains(process)': False,
#   'contains(120)': False,
#   'contains(based)': False,
#   'contains(h)': False,
#   'contains(place)': False,
#   'contains(stop)': False,
#   'contains(jan)': False,
#   'contains(marketing)': False,
#   'contains(viagra)': False,
#   'contains(data)': False,
#   'contains(george)': False,
#   'contains(good)': False,
#   'contains(computron)': False,
#   'contains(check)': False,
#   'contains(tom)': False,
#   'contains(internet)': False,
#   'contains(people)': False,
#   'contains(look)': False,
#   'contains(securities)': False,
#   'contains(professional)': False,
#   'contains(hplc)': False,
#   'contains(28)': False,
#   'contains(anita)': False,
#   'contains(29)': False,
#   'contains(julie)': False,
#   'contains(america)': False,
#   'contains(site)': False,
#   'contains(find)': False,
#   'contains(receive)': False,
#   'contains(risk)': True,
#   'contains(reply)': False,
#   'contains(mary)': False,
#   'contains(45)': False,
#   'contains(pg)': False,
#   'contains(international)': False,
#   'contains(market)': False,
#   'contains(february)': False,
#   'contains(world)': False,
#   'contains(susan)': False,
#   'contains(tickets)': False,
#   'contains(since)': False,
#   'contains(meters)': False,
#   'contains(much)': False,
#   'contains(purchase)': False,
#   'contains(sure)': False,
#   'contains(young)': False,
#   'contains(howard)': False,
#   'contains(provide)': False,
#   'contains(home)': False,
#   'contains(rates)': False,
#   'contains(44)': False,
#   'contains(07)': False,
#   'contains(unify)': False,
#   'contains(high)': False,
#   'contains(26)': False,
#   'contains(pipeline)': False,
#   'contains(\x01)': False,
#   'contains(development)': False,
#   'contains(brenda)': False,
#   'contains(xp)': False,
#   'contains(smith)': False,
#   'contains(visit)': False,
#   'contains(center)': False,
#   'contains(north)': False,
#   'contains(right)': False,
#   'contains(st)': False,
#   'contains(request)': False,
#   'contains(problem)': False,
#   'contains(great)': False,
#   'contains(total)': False,
#   'contains(activity)': False,
#   'contains(financial)': False,
#   'contains(point)': False,
#   'contains(needed)': False,
#   'contains(`)': False,
#   'contains(operations)': False,
#   'contains(2003)': False,
#   'contains(companies)': False,
#   'contains(product)': False,
#   'contains(friday)': False,
#   'contains(meds)': False,
#   'contains(end)': False,
#   'contains(still)': False,
#   'contains(id)': False,
#   'contains(80)': False,
#   'contains(less)': False,
#   'contains(issue)': False,
#   'contains(1999)': False,
#   'contains(lisa)': False,
#   'contains(daily)': True,
#   'contains(show)': False,
#   'contains(low)': False,
#   'contains(stephanie)': False,
#   'contains(713)': False,
#   'contains(plant)': False,
#   'contains(note)': False,
#   'contains(noms)': False,
#   'contains(must)': False,
#   'contains(news)': False,
#   'contains(keep)': False,
#   'contains(full)': False,
#   'contains(quality)': False,
#   'contains(trading)': False,
#   'contains(html)': False,
#   'contains(lloyd)': False,
#   'contains(rate)': False,
#   'contains(index)': False,
#   'contains(transaction)': False,
#   'contains(support)': False,
#   'contains(revised)': False,
#   'contains(adobe)': False,
#   'contains(entex)': False,
#   'contains(additional)': False,
#   'contains(security)': False,
#   'contains(copy)': False,
#   'contains(prescription)': False,
#   'contains(ces)': False,
#   'contains(global)': True,
#   'contains(issues)': False,
#   'contains(performance)': False,
#   'contains(paliourg)': False,
#   'contains(increase)': False,
#   'contains(currently)': False,
#   'contains(32)': False,
#   'contains(fred)': False,
#   'contains(camp)': False,
#   'contains(hi)': False,
#   'contains(offers)': False,
#   'contains(remove)': False,
#   'contains(long)': False,
#   'contains(pops)': False,
#   'contains(think)': False,
#   'contains(going)': False,
#   'contains(numbers)': False,
#   'contains(agreement)': False,
#   'contains(via)': False,
#   'contains(herod)': False,
#   'contains(hours)': False,
#   'contains(come)': False,
#   'contains(every)': False,
#   'contains(500)': False,
#   'contains(access)': False,
#   'contains(fyi)': False,
#   'contains(bob)': False,
#   'contains(bgcolor)': False,
#   'contains(luong)': False,
#   'contains(used)': False,
#   'contains(sell)': False,
#   'contains(put)': False,
#   'contains(months)': False,
#   'contains(someone)': False,
#   'contains(control)': False,
#   'contains(using)': False,
#   'contains(position)': False,
#   'contains(review)': False,
#   'contains(prior)': False,
#   'contains(dollars)': False,
#   'contains(stella)': False,
#   'contains(working)': False,
#   'contains(done)': False,
#   'contains(clynes)': False,
#   'contains(possible)': False,
#   'contains(midcon)': False,
#   'contains(part)': False,
#   'contains(eastrans)': False,
#   'contains(cd)': False,
#   'contains(believe)': False,
#   'contains(soon)': False,
#   'contains(notice)': False,
#   'contains(contracts)': False,
#   'contains(start)': False,
#   'contains(results)': False,
#   'contains(limited)': False,
#   'contains(act)': False,
#   'contains(details)': False,
#   'contains(counterparty)': False,
#   'contains(received)': False,
#   'contains(michael)': False,
#   'contains(cialis)': False,
#   'contains(allen)': False,
#   'contains(pay)': False,
#   'contains(accounting)': False,
#   'contains(35)': False,
#   'contains(content)': False,
#   'contains(health)': False,
#   'contains(biz)': False,
#   'contains(95)': False,
#   'contains(works)': False,
#   'contains(pro)': False,
#   'contains(charlotte)': False,
#   'contains(web)': False,
#   'contains(meyers)': False,
#   'contains(weight)': False,
#   'contains(required)': False,
#   'contains(mg)': False,
#   'contains(brian)': False,
#   'contains(project)': False,
#   'contains(duke)': False,
#   'contains(retail)': False,
#   'contains(cash)': False,
#   'contains(newsletter)': False,
#   'contains(got)': False,
#   'contains(even)': False,
#   'contains(life)': False,
#   'contains(stacey)': False,
#   'contains(storage)': False,
#   'contains(strong)': False,
#   'contains(jpg)': False,
#   'contains(124)': False,
#   'contains(natural)': False,
#   'contains(monday)': False,
#   'contains(reports)': False,
#   'contains(scott)': False,
#   'contains(customer)': False,
#   'contains(correct)': False,
#   'contains(current)': False,
#   'contains(survey)': False,
#   'contains(ranch)': False,
#   'contains(manager)': False,
#   'contains(loss)': False,
#   'contains(real)': False,
#   'contains(dec)': False,
#   'contains(power)': False,
#   'contains(fax)': False,
#   'contains(section)': False,
#   'contains(allocated)': False,
#   'contains(resources)': False,
#   'contains(easy)': False,
#   'contains(east)': False,
#   'contains(including)': False,
#   'contains(interest)': False,
#   'contains(type)': False,
#   'contains(phone)': False,
#   'contains(thu)': False,
#   'contains(de)': False,
#   'contains(feel)': False,
#   'contains(private)': False,
#   'contains(stocks)': False,
#   'contains(vance)': False,
#   'contains(carthage)': False,
#   'contains(hsc)': False,
#   'contains(follow)': False,
#   'contains(advice)': False,
#   'contains(top)': False,
#   'contains(commercial)': False,
#   'contains(gif)': False,
#   'contains(000000)': False,
#   'contains(way)': False,
#   'contains(july)': False,
#   'contains(never)': False,
#   'contains(able)': False,
#   'contains(scheduled)': False,
#   'contains(moopid)': False,
#   'contains(hotlist)': False,
#   'contains(complete)': False,
#   'contains(drugs)': False,
#   'contains(getting)': False,
#   'contains(city)': False,
#   'contains(lannou)': False,
#   'contains(corporation)': False,
#   'contains(cost)': False,
#   'contains(read)': False,
#   'contains(pain)': False,
#   'contains(div)': False,
#   'contains(oil)': False,
#   'contains(however)': False,
#   'contains(program)': False,
#   'contains(removed)': False,
#   'contains(page)': False,
#   'contains(move)': False,
#   'contains(include)': False,
#   'contains(houston)': False,
#   'contains(man)': False,
#   'contains(costs)': False,
#   'contains(old)': False,
#   'contains(tuesday)': False,
#   'contains(receipt)': False,
#   'contains(said)': False,
#   'contains(rc)': False,
#   'contains(release)': False,
#   'contains(body)': False,
#   'contains(table)': False,
#   'contains(valid)': False,
#   'contains(david)': False,
#   'contains(provided)': False,
#   'contains(taylor)': False,
#   'contains(country)': False,
#   'contains(error)': False,
#   'contains(try)': False,
#   'contains(xanax)': False,
#   'contains(form)': False,
#   'contains(open)': False,
#   'contains(mar)': False,
#   'contains(necessary)': False,
#   'contains(co)': False,
#   'contains(htmlimg)': False,
#   'contains(another)': False,
#   'contains(anything)': False,
#   'contains(better)': False,
#   'contains(suite)': False,
#   'contains(shipping)': False,
#   'contains(continue)': False,
#   'contains(past)': False,
#   'contains(calls)': False,
#   'contains(\\)': False,
#   'contains(buyback)': False,
#   'contains(clear)': False,
#   'contains(party)': False,
#   'contains(third)': False,
#   'contains(regarding)': False,
#   'contains(update)': False,
#   'contains(images)': False,
#   'contains(book)': False,
#   'contains(yet)': False,
#   'contains(zero)': False,
#   'contains(bryan)': False,
#   'contains(original)': False,
#   'contains(200)': False,
#   'contains(cotton)': False,
#   'contains(55)': False,
#   'contains(ever)': False,
#   'contains(systems)': False,
#   'contains(investing)': False,
#   'contains(36)': False,
#   'contains(source)': False,
#   'contains(add)': False,
#   'contains(morning)': False,
#   'contains(flowed)': False,
#   'contains(melissa)': False,
#   'contains(fuels)': False,
#   'contains(path)': False,
#   'contains(spam)': False,
#   'contains(always)': False,
#   'contains(mark)': False,
#   'contains(regards)': False,
#   'contains(super)': False,
#   'contains(valium)': False,
#   'contains(united)': False,
#   'contains(ken)': False,
#   'contains(everyone)': False,
#   'contains(215)': False,
#   'contains(lst)': False,
#   'contains(everything)': False,
#   'contains(application)': False,
#   'contains(800)': False,
#   'contains(300)': False,
#   'contains(something)': False,
#   'contains(love)': False,
#   'contains(70)': False,
#   'contains(found)': False,
#   'contains(case)': False,
#   'contains(term)': False,
#   'contains(ensure)': False,
#   'contains(charge)': False,
#   'contains(fill)': False,
#   'contains(three)': False,
#   'contains(shares)': False,
#   'contains(img)': False,
#   'contains(jennifer)': False,
#   'contains(box)': False,
#   'contains(either)': False,
#   'contains(left)': False,
#   'contains(valley)': False,
#   'contains(cause)': False,
#   'contains(transfer)': False,
#   'contains(cheap)': False,
#   'contains(zone)': False,
#   'contains(estimates)': False,
#   'contains(sally)': False,
#   'contains(department)': False,
#   'contains(php)': False,
#   'contains(server)': False,
#   'contains(south)': False,
#   'contains(technology)': False,
#   'contains(aol)': False,
#   'contains(encina)': False,
#   'contains(weekend)': False,
#   'contains(acton)': False,
#   'contains(close)': False,
#   'contains(little)': False,
#   'contains(duty)': False,
#   'contains(already)': False,
#   'contains(75)': False,
#   'contains(cs)': False,
#   'contains(wish)': False,
#   'contains(public)': False,
#   'contains(mobile)': False,
#   'contains(late)': False,
#   'contains(hanks)': False,
#   'contains(communications)': False,
#   'contains(music)': False,
#   'contains(equistar)': False,
#   'contains(john)': False,
#   'contains(created)': False,
#   'contains(industry)': False,
#   'contains(sherlyn)': False,
#   'contains(different)': False,
#   'contains(fact)': False,
#   'contains(trade)': False,
#   'contains(~)': False,
#   'contains(direct)': False,
#   'contains(drive)': False,
#   'contains(years)': False,
#   'contains(quick)': False,
#   'contains(pricing)': False,
#   'contains(browser)': False,
#   'contains(second)': False,
#   'contains(customers)': False,
#   'contains(photoshop)': False,
#   'contains(head)': False,
#   'contains(field)': False,
#   'contains(text)': False,
#   'contains(thomas)': False,
#   'contains(ms)': False,
#   'contains(side)': False,
#   'contains(longer)': False,
#   'contains(around)': False,
#   'contains(worldwide)': False,
#   'contains(anyone)': False,
#   'contains(37)': False,
#   'contains(credit)': False,
#   'contains(lose)': False,
#   'contains(states)': False,
#   'contains(generic)': False,
#   'contains(morris)': False,
#   'contains(gco)': False,
#   'contains(reliantenergy)': False,
#   'contains(remember)': False,
#   'contains(56)': False,
#   'contains(canada)': False,
#   'contains(really)': False,
#   'contains(view)': False,
#   'contains(play)': False,
#   'contains(registered)': False,
#   'contains(devon)': False,
#   'contains(problems)': False,
#   'contains(publisher)': False,
#   'contains(wanted)': False,
#   'contains(else)': False,
#   'contains(december)': False,
#   'contains(etc)': False,
#   'contains(012)': False,
#   'contains(sold)': False,
#   'contains(paste)': False,
#   'contains(hey)': False,
#   'contains(methanol)': False,
#   'contains(major)': False,
#   'contains(soft)': False,
#   'contains(men)': False,
#   'contains(fuel)': False,
#   'contains(gcs)': False,
#   'contains(cec)': False,
#   'contains(unsubscribe)': False,
#   'contains(james)': False,
#   'contains(ees)': False,
#   'contains(schedule)': False,
#   'contains(lauri)': False,
#   'contains(boas)': False,
#   'contains(gomes)': False,
#   'contains(plan)': False,
#   'contains(logistics)': False,
#   'contains(33)': False,
#   'contains(reason)': False,
#   'contains(press)': False,
#   'contains(actual)': False,
#   'contains(52)': False,
#   'contains(person)': False,
#   'contains(withers)': False,
#   'contains(fund)': False,
#   'contains(family)': False,
#   'contains(cf)': False,
#   'contains(dear)': False,
#   'contains(thursday)': False,
#   'contains(secure)': False,
#   'contains(key)': False,
#   'contains(training)': False,
#   'contains(features)': False,
#   'contains(hawkins)': False,
#   'contains(growth)': False,
#   'contains(beaumont)': False,
#   'contains(compliance)': False,
#   'contains(reveffo)': False,
#   'contains(graves)': False,
#   'contains(plus)': False,
#   'contains(version)': False,
#   'contains(small)': False,
#   'contains(swing)': False,
#   'contains(bank)': False,
#   'contains(hard)': False,
#   'contains(medications)': False,
#   'contains(kind)': False,
#   'contains(area)': False,
#   'contains(allow)': False,
#   'contains(solution)': False,
#   'contains(})': False,
#   'contains(level)': False,
#   'contains(material)': False,
#   'contains(34)': False,
#   'contains(user)': False,
#   'contains(allocation)': False,
#   'contains(im)': False,
#   'contains(personal)': False,
#   'contains(teco)': False,
#   'contains(president)': False,
#   'contains(ali)': False,
#   'contains(darial)': False,
#   'contains(lee)': True,
#   'contains(kenneth)': False,
#   'contains(rita)': False,
#   'contains(valero)': False,
#   'contains(learn)': False,
#   'contains(carlos)': False,
#   'contains(spot)': False,
#   'contains(rd)': False,
#   'contains(mid)': False,
#   'contains(48)': False,
#   'contains(meet)': False,
#   'contains(legal)': False,
#   'contains(bill)': False,
#   'contains(approximately)': False,
#   'contains(download)': False,
#   'contains(gr)': False,
#   'contains(trevino)': False,
#   'contains(fw)': False,
#   'contains(shut)': False,
#   'contains(·)': False,
#   'contains(0310041)': False,
#   'contains(king)': False,
#   'contains(aware)': False,
#   'contains(cut)': False,
#   'contains(amount)': False,
#   'contains(sex)': False,
#   'contains(experience)': False,
#   'contains(doctor)': False,
#   'contains(nominations)': False,
#   'contains(making)': False,
#   'contains(panenergy)': False,
#   'contains(hope)': False,
#   'contains(called)': False,
#   'contains(thing)': False,
#   'contains(therefore)': False,
#   'contains(tell)': False,
#   'contains(mr)': False,
#   'contains(network)': False,
#   'contains(updated)': False,
#   'contains(might)': False,
#   'contains(imbalance)': False,
#   'contains(supply)': False,
#   'contains(property)': False,
#   'contains(prize)': False,
#   'contains(cds)': False,
#   'contains(wellhead)': False,
#   'contains(things)': False,
#   'contains(58)': False,
#   'contains(42)': False,
#   'contains(paid)': False,
#   'contains(addition)': False,
#   'contains(begin)': False,
#   'contains(39)': False,
#   'contains(events)': False,
#   'contains(weeks)': False,
#   'contains(latest)': False,
#   'contains(several)': False,
#   'contains(interested)': False,
#   'contains(49)': False,
#   'contains(shows)': False,
#   'contains(tina)': False,
#   'contains(safe)': False,
#   'contains(related)': False,
#   'contains(directly)': False,
#   'contains(hello)': False,
#   'contains(yvette)': False,
#   'contains(china)': False,
#   'contains(federal)': False,
#   'contains(whole)': False,
#   'contains(expected)': False,
#   'contains(options)': False,
#   'contains(pc)': False,
#   'contains(iit)': False,
#   'contains(demokritos)': False,
#   'contains(approved)': False,
#   'contains(dave)': False,
#   'contains(gold)': False,
#   'contains(title)': False,
#   'contains(neuweiler)': False,
#   'contains(971)': False,
#   'contains(mx)': False,
#   'contains(0424040)': False,
#   'contains(ftar)': False,
#   'contains(given)': False,
#   'contains(feedback)': False,
#   'contains(research)': False,
#   'contains(38)': False,
#   'contains(bridge)': False,
#   'contains(fast)': False,
#   'contains(create)': False,
#   'contains(confirm)': False,
#   'contains(understand)': False,
#   'contains(thru)': False,
#   'contains(thought)': False,
#   'contains(lp)': False,
#   'contains(status)': False,
#   'contains(letter)': False,
#   'contains(monthly)': False,
#   'contains(large)': False,
#   'contains(away)': False,
#   'contains(kimberly)': False,
#   'contains(q)': False,
#   'contains(follows)': False,
#   'contains(yahoo)': False,
#   'contains({)': False,
#   'contains(takes)': False,
#   'contains(exchange)': False,
#   'contains(effort)': False,
#   'contains(pipe)': False,
#   'contains(starting)': False,
#   'contains(41)': False,
#   'contains(enough)': False,
#   'contains(words)': False,
#   'contains(egmnom)': False,
#   'contains(firm)': False,
#   'contains(exxon)': False,
#   'contains(changed)': True,
#   'contains(wynne)': False,
#   'contains(vicodin)': False,
#   'contains(fat)': False,
#   'contains(9497)': False,
#   'contains(computer)': False,
#   'contains(action)': False,
#   'contains(pharmacy)': False,
#   'contains(wednesday)': False,
#   'contains(operating)': False,
#   'contains(ability)': False,
#   'contains(soma)': False,
#   'contains(others)': False,
#   'contains(brand)': False,
#   'contains(dvd)': False,
#   'contains(gathering)': False,
#   'contains(understanding)': False,
#   'contains(listing)': False,
#   'contains(josey)': False,
#   'contains(receiving)': False,
#   'contains(exploration)': False,
#   'contains(wide)': False,
#   'contains(0986725)': False,
#   'contains(requested)': False,
#   'contains(valadez)': False,
#   'contains(period)': False,
#   'contains(usa)': False,
#   'contains(cover)': False,
#   'contains(assistance)': False,
#   'contains(rest)': False,
#   'contains(enter)': False,
#   'contains(requirements)': False,
#   'contains(ltd)': False,
#   'contains(advise)': False,
#   'contains(megan)': False,
#   'contains(shipped)': False,
#   'contains(say)': False,
#   'contains(expense)': False,
#   'contains(54)': False,
#   'contains(voice)': False,
#   'contains(relief)': False,
#   'contains(bruce)': False,
#   'contains(ship)': False,
#   'contains(katherine)': False,
#   'contains(57)': False,
#   'contains(run)': False,
#   'contains(times)': False,
#   'contains(revision)': False,
#   'contains(asap)': False,
#   'contains(members)': False,
#   'contains(shall)': False,
#   'contains(entered)': False,
#   'contains(offering)': False,
#   'contains(nothing)': False,
#   'contains(cheryl)': False,
#   'contains(potential)': False,
#   'contains(estimate)': False,
#   'contains(asked)': False,
#   'contains(card)': False,
#   'contains(watch)': False,
#   'contains(union)': False,
#   'contains(recent)': False,
#   'contains(distribution)': False,
#   'contains(donna)': False,
#   'contains(says)': False,
#   'contains(redeliveries)': False,
#   'contains(gra)': False,
#   'contains(ei)': False,
#   'contains(hotmail)': False,
#   'contains(tx)': False,
#   'contains(william)': False,
#   'contains(nominated)': False,
#   'contains(ua)': False,
#   'contains(oasis)': False,
#   'contains(specials)': False,
#   'contains(actuals)': False,
#   'contains(prc)': False,
#   'contains(fontfont)': False,
#   'contains(1226030)': False,
#   'contains(reflect)': False,
#   'contains(jim)': False,
#   'contains(invoices)': False,
#   'contains(response)': False,
#   'contains(rx)': False,
#   'contains(settlements)': False,
#   'contains(selected)': False,
#   'contains(items)': False,
#   'contains(air)': False,
#   'contains(overnight)': False,
#   'contains(door)': False,
#   'contains(corel)': False,
#   'contains(deliveries)': False,
#   'contains(revenue)': False,
#   'contains(website)': False,
#   'contains(usb)': False,
#   'contains(code)': False,
#   'contains(97)': False,
#   'contains(processing)': False,
#   'contains(eol)': False,
#   'contains(°)': False,
#   'contains(taken)': True,
#   'contains(troy)': False,
#   'contains(assist)': False,
#   'contains(availability)': False,
#   'contains(probably)': False,
#   'contains(listed)': False,
#   'contains(tomorrow)': False,
#   'contains(profile)': False,
#   'contains(crow)': False,
#   'contains(connor)': False,
#   'contains(track)': False,
#   'contains(taking)': False,
#   'contains(sincerely)': False,
#   'contains(cellpadding)': False,
#   'contains(passed)': False,
#   'contains(holmes)': False,
#   'contains(sorry)': False,
#   'contains(style)': False,
#   'contains(expectations)': False,
#   'contains(intended)': False,
#   'contains(nguyen)': False,
#   'contains(heidi)': False,
#   'contains(media)': False,
#   'contains(texaco)': False,
#   'contains(golf)': False,
#   ...},
#  'ham')

# %%
#Naive Bayes classifier with 5-fold cross validation for training on sentiments using
#unigrams without stopwords and certain punctuation

start = time.time()
kf = KFold(n_splits = num_split)
sum = 0
prec = 0
recall = 0

for train, test in kf.split(featuresets3):
    train_data = np.array(featuresets3)[train]
    test_data = np.array(featuresets3)[test]
    classifier = nltk.NaiveBayesClassifier.train(train_data)
    sum += nltk.classify.accuracy(classifier, test_data)
    
    #calculating precision and recall 
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)

    for i, (feats, label) in enumerate(test_data):
        refsets[label].add(i)
        observed = classifier.classify(feats)
        testsets[observed].add(i)
    
    prec += nltk.precision(refsets['spam'], testsets['spam'])
    recall += nltk.recall(refsets['spam'], testsets['spam'])

#storing the score in a variable 
acc3 = sum/num_split
avg_precision3 = prec/num_split
avg_recall3 = recall/num_split

end = time.time()
print("Processing Time: {0:.2f} seconds".format(end - start))

#let's see the accuracy score for this new classifier
print("Accuracy:", round(acc3,4))
print("Precision:", round(avg_precision3,4))
print("Recall:", round(avg_recall3,4))
# Out:
# Processing Time: 29.85 seconds
# Accuracy: 0.9615
# Precision: 0.9297
# Recall: 0.999

# %%
## EXPERIMENT 3 - INCREASE THE FEATURE VOCABULARY##
top_words = nltk.FreqDist(all_words)
most_common_words = top_words.most_common(5000)
word_features4 = [word for (word,count) in most_common_words]
word_features4[:20]
# Out:
# ['-',
#  '.',
#  '/',
#  ',',
#  ':',
#  'the',
#  'to',
#  'ect',
#  'and',
#  '@',
#  'of',
#  'a',
#  'for',
#  'you',
#  'in',
#  'is',
#  'this',
#  'hou',
#  'on',
#  '=']

# %%
#now we apply the function to the document dataset
featuresets4 = [(document_features(d, word_features4), c) for (d, c) in emaildocs]

#we print the list of features matches for the first document ([0]) in the corpus
featuresets4[0]
# Out:
# ({'contains(-)': False,
#   'contains(.)': True,
#   'contains(/)': False,
#   'contains(,)': True,
#   'contains(:)': True,
#   'contains(the)': True,
#   'contains(to)': True,
#   'contains(ect)': False,
#   'contains(and)': False,
#   'contains(@)': False,
#   'contains(of)': True,
#   'contains(a)': False,
#   'contains(for)': True,
#   'contains(you)': True,
#   'contains(in)': False,
#   'contains(is)': False,
#   'contains(this)': False,
#   'contains(hou)': False,
#   'contains(on)': False,
#   'contains(=)': False,
#   'contains(?)': False,
#   'contains(i)': True,
#   "contains(')": True,
#   'contains())': False,
#   'contains(()': False,
#   'contains(Subject)': True,
#   'contains(!)': False,
#   'contains(your)': False,
#   'contains(that)': False,
#   'contains(be)': True,
#   'contains(2000)': False,
#   'contains(enron)': False,
#   'contains(with)': False,
#   'contains(will)': True,
#   'contains(we)': False,
#   'contains(have)': False,
#   'contains(3)': False,
#   'contains(from)': False,
#   'contains($)': False,
#   'contains(s)': False,
#   'contains(as)': False,
#   'contains(at)': False,
#   'contains(are)': False,
#   'contains(it)': False,
#   'contains(by)': True,
#   'contains(please)': False,
#   'contains(not)': False,
#   'contains(``)': False,
#   'contains(if)': True,
#   'contains(1)': False,
#   'contains(or)': False,
#   'contains(com)': False,
#   'contains(_)': False,
#   'contains(*)': False,
#   'contains(;)': False,
#   'contains(me)': False,
#   'contains(2)': False,
#   'contains(e)': False,
#   'contains(%)': False,
#   'contains(00)': False,
#   'contains(#)': True,
#   'contains(all)': False,
#   'contains(d)': False,
#   'contains(our)': False,
#   'contains(>)': False,
#   'contains(subject)': False,
#   'contains(meter)': False,
#   'contains(can)': False,
#   'contains(am)': False,
#   'contains(pm)': False,
#   'contains(gas)': True,
#   'contains(cc)': False,
#   'contains(deal)': False,
#   'contains(any)': True,
#   'contains(0)': True,
#   'contains(http)': False,
#   'contains(99)': False,
#   'contains(000)': False,
#   'contains(no)': False,
#   'contains(has)': False,
#   'contains(corp)': False,
#   'contains(new)': False,
#   'contains(thanks)': False,
#   'contains(get)': False,
#   'contains(an)': False,
#   'contains(re)': False,
#   'contains(10)': False,
#   'contains(was)': False,
#   'contains(up)': False,
#   'contains(4)': False,
#   'contains(5)': False,
#   'contains(&)': False,
#   'contains(know)': False,
#   'contains(t)': False,
#   'contains(here)': False,
#   'contains(|)': False,
#   'contains(need)': False,
#   'contains(more)': False,
#   'contains(forwarded)': False,
#   'contains(03)': False,
#   'contains(out)': False,
#   'contains(12)': False,
#   'contains(do)': False,
#   'contains(p)': False,
#   'contains(only)': False,
#   'contains(may)': False,
#   'contains(daren)': False,
#   'contains(hpl)': False,
#   'contains(there)': False,
#   'contains(7)': False,
#   'contains(information)': False,
#   'contains(these)': False,
#   'contains(into)': False,
#   'contains(my)': False,
#   'contains(us)': False,
#   'contains(company)': False,
#   'contains(01)': False,
#   'contains(mmbtu)': False,
#   'contains(05)': False,
#   'contains(www)': False,
#   'contains(04)': False,
#   'contains(02)': False,
#   'contains(l)': False,
#   'contains(let)': False,
#   'contains(time)': False,
#   'contains(would)': False,
#   'contains(but)': True,
#   'contains(so)': False,
#   'contains(6)': False,
#   'contains(m)': False,
#   'contains(been)': False,
#   'contains(11)': False,
#   'contains(price)': False,
#   'contains(b)': False,
#   'contains(one)': True,
#   'contains(should)': False,
#   'contains(now)': False,
#   'contains(th)': False,
#   'contains(month)': False,
#   'contains(mail)': False,
#   'contains(contract)': False,
#   'contains(8)': False,
#   'contains(td)': False,
#   'contains(email)': False,
#   'contains(nbsp)': False,
#   'contains(sitara)': True,
#   'contains(what)': False,
#   'contains(see)': False,
#   'contains(20)': False,
#   'contains(j)': False,
#   'contains(])': False,
#   'contains([)': False,
#   'contains(which)': False,
#   'contains(day)': False,
#   'contains(x)': False,
#   'contains(also)': False,
#   'contains(15)': False,
#   'contains(volume)': False,
#   'contains(they)': False,
#   'contains(about)': False,
#   'contains(free)': False,
#   'contains(like)': False,
#   'contains(energy)': False,
#   'contains(c)': False,
#   'contains(deals)': False,
#   'contains(font)': False,
#   'contains(their)': False,
#   'contains(pills)': False,
#   'contains(some)': False,
#   'contains(change)': False,
#   'contains(ami)': False,
#   'contains(30)': False,
#   'contains(business)': False,
#   'contains(just)': False,
#   'contains(o)': False,
#   'contains(message)': False,
#   'contains(want)': False,
#   'contains(r)': False,
#   'contains(volumes)': False,
#   'contains(2004)': False,
#   'contains(over)': False,
#   'contains(attached)': False,
#   'contains(other)': False,
#   'contains(+)': False,
#   'contains(farmer)': False,
#   'contains(xls)': False,
#   'contains(09)': False,
#   'contains(its)': False,
#   'contains(questions)': False,
#   'contains(who)': False,
#   'contains(contact)': False,
#   'contains(9)': False,
#   'contains(when)': False,
#   'contains(make)': False,
#   'contains(width)': False,
#   'contains(report)': False,
#   'contains(25)': False,
#   'contains(60)': False,
#   'contains(call)': False,
#   'contains(06)': False,
#   'contains(list)': False,
#   'contains(click)': False,
#   'contains(back)': False,
#   'contains(money)': False,
#   'contains(f)': False,
#   'contains(100)': False,
#   'contains(texas)': False,
#   'contains(could)': False,
#   'contains(nom)': False,
#   'contains(set)': False,
#   'contains(chokshi)': False,
#   'contains(inc)': False,
#   'contains(robert)': False,
#   'contains(he)': False,
#   'contains(height)': False,
#   'contains(following)': False,
#   'contains(order)': False,
#   'contains(24)': False,
#   'contains(50)': False,
#   'contains(how)': False,
#   'contains(forward)': False,
#   'contains(production)': False,
#   'contains(08)': False,
#   'contains(w)': False,
#   'contains(below)': False,
#   'contains(them)': False,
#   'contains(january)': False,
#   'contains(21)': False,
#   'contains(per)': False,
#   'contains(today)': False,
#   'contains(statements)': False,
#   'contains(march)': False,
#   'contains(best)': False,
#   'contains(sale)': False,
#   'contains(ena)': False,
#   'contains(number)': False,
#   'contains(k)': False,
#   'contains(available)': False,
#   'contains(first)': False,
#   'contains(g)': False,
#   'contains(through)': False,
#   'contains(take)': True,
#   'contains(31)': False,
#   'contains(system)': False,
#   'contains(align)': False,
#   'contains(sent)': False,
#   'contains(were)': False,
#   'contains(go)': False,
#   'contains(days)': False,
#   'contains(she)': False,
#   'contains(help)': False,
#   'contains(don)': False,
#   'contains(management)': False,
#   'contains(98)': False,
#   'contains(stock)': False,
#   'contains(jackie)': False,
#   'contains(u)': False,
#   'contains(v)': False,
#   'contains(tr)': False,
#   'contains(online)': False,
#   'contains(23)': False,
#   'contains(ticket)': True,
#   'contains(changes)': False,
#   'contains(june)': False,
#   'contains(size)': False,
#   'contains(within)': False,
#   'contains(n)': False,
#   'contains(14)': False,
#   'contains(flow)': False,
#   'contains(border)': False,
#   'contains(info)': False,
#   'contains(last)': False,
#   'contains(18)': False,
#   'contains(nd)': False,
#   'contains(well)': False,
#   'contains(than)': True,
#   'contains(group)': False,
#   'contains(16)': False,
#   'contains(most)': False,
#   'contains(gary)': False,
#   'contains(address)': False,
#   'contains(service)': False,
#   'contains(next)': False,
#   'contains(had)': False,
#   'contains(team)': False,
#   'contains(transport)': False,
#   'contains(pec)': False,
#   'contains(his)': False,
#   'contains(effective)': False,
#   'contains(work)': False,
#   'contains(each)': False,
#   'contains(color)': False,
#   'contains(april)': False,
#   'contains(due)': False,
#   'contains(face)': False,
#   'contains(use)': False,
#   'contains(account)': False,
#   'contains(buy)': False,
#   'contains(sales)': False,
#   'contains(looking)': False,
#   'contains(69)': False,
#   'contains(22)': False,
#   'contains(nomination)': False,
#   'contains(many)': False,
#   'contains(office)': False,
#   'contains(without)': False,
#   'contains(after)': False,
#   'contains(offer)': False,
#   'contains(microsoft)': False,
#   "contains('')": False,
#   'contains(net)': False,
#   'contains(services)': False,
#   'contains(week)': False,
#   'contains(prices)': False,
#   'contains(name)': False,
#   'contains(before)': False,
#   'contains(same)': False,
#   'contains(because)': False,
#   'contains(63)': False,
#   'contains(year)': False,
#   'contains(19)': False,
#   'contains(feb)': False,
#   'contains(save)': False,
#   'contains(delivery)': False,
#   'contains(17)': False,
#   'contains(line)': False,
#   'contains(thank)': False,
#   'contains(link)': False,
#   'contains(send)': False,
#   'contains(aimee)': False,
#   'contains(special)': False,
#   'contains(13)': False,
#   'contains(date)': False,
#   'contains(desk)': False,
#   'contains(million)': False,
#   'contains(27)': False,
#   'contains(being)': False,
#   'contains(file)': False,
#   'contains(40)': False,
#   'contains(investment)': False,
#   'contains(href)': False,
#   'contains(src)': False,
#   'contains(off)': True,
#   'contains(products)': False,
#   'contains(90)': False,
#   'contains(made)': False,
#   'contains(br)': False,
#   'contains(pat)': False,
#   'contains(future)': False,
#   'contains(needs)': True,
#   'contains(then)': False,
#   'contains(where)': False,
#   'contains(software)': False,
#   'contains(161)': False,
#   'contains(two)': False,
#   'contains(give)': False,
#   'contains(steve)': False,
#   'contains(windows)': False,
#   'contains(above)': False,
#   'contains(meeting)': False,
#   'contains(process)': False,
#   'contains(120)': False,
#   'contains(based)': False,
#   'contains(does)': False,
#   'contains(h)': False,
#   'contains(place)': False,
#   'contains(stop)': False,
#   'contains(jan)': False,
#   'contains(marketing)': False,
#   'contains(viagra)': False,
#   'contains(data)': False,
#   'contains(george)': False,
#   'contains(did)': False,
#   'contains(good)': False,
#   'contains(computron)': False,
#   'contains(check)': False,
#   'contains(tom)': False,
#   'contains(very)': False,
#   'contains(such)': False,
#   'contains(internet)': False,
#   'contains(people)': False,
#   'contains(look)': False,
#   'contains(securities)': False,
#   'contains(professional)': False,
#   'contains(hplc)': False,
#   'contains(28)': False,
#   'contains(anita)': False,
#   'contains(29)': False,
#   'contains(julie)': False,
#   'contains(america)': False,
#   'contains(site)': False,
#   'contains(find)': False,
#   'contains(receive)': False,
#   'contains(down)': False,
#   'contains(risk)': True,
#   'contains(reply)': False,
#   'contains(under)': False,
#   'contains(mary)': False,
#   'contains(45)': False,
#   'contains(pg)': False,
#   'contains(international)': False,
#   'contains(market)': False,
#   'contains(february)': False,
#   'contains(world)': False,
#   'contains(susan)': False,
#   'contains(tickets)': False,
#   'contains(since)': False,
#   'contains(meters)': False,
#   'contains(much)': False,
#   'contains(purchase)': False,
#   'contains(sure)': False,
#   'contains(those)': False,
#   'contains(young)': False,
#   'contains(howard)': False,
#   'contains(provide)': False,
#   'contains(home)': False,
#   'contains(rates)': False,
#   'contains(44)': False,
#   'contains(07)': False,
#   'contains(unify)': False,
#   'contains(high)': False,
#   'contains(26)': False,
#   'contains(pipeline)': False,
#   'contains(ll)': False,
#   'contains(her)': False,
#   'contains(\x01)': False,
#   'contains(development)': False,
#   'contains(brenda)': False,
#   'contains(xp)': False,
#   'contains(smith)': False,
#   'contains(visit)': False,
#   'contains(center)': False,
#   'contains(north)': False,
#   'contains(both)': False,
#   'contains(again)': False,
#   'contains(right)': False,
#   'contains(st)': False,
#   'contains(request)': False,
#   'contains(problem)': False,
#   'contains(great)': False,
#   'contains(total)': False,
#   'contains(activity)': False,
#   'contains(financial)': False,
#   'contains(point)': False,
#   'contains(needed)': False,
#   'contains(`)': False,
#   'contains(operations)': False,
#   'contains(2003)': False,
#   'contains(companies)': False,
#   'contains(product)': False,
#   'contains(ve)': True,
#   'contains(friday)': False,
#   'contains(meds)': False,
#   'contains(end)': False,
#   'contains(still)': False,
#   'contains(id)': False,
#   'contains(80)': False,
#   'contains(less)': False,
#   'contains(issue)': False,
#   'contains(1999)': False,
#   'contains(lisa)': False,
#   'contains(daily)': True,
#   'contains(show)': False,
#   'contains(low)': False,
#   'contains(stephanie)': False,
#   'contains(713)': False,
#   'contains(plant)': False,
#   'contains(note)': False,
#   'contains(noms)': False,
#   'contains(must)': False,
#   'contains(news)': False,
#   'contains(keep)': False,
#   'contains(full)': False,
#   'contains(quality)': False,
#   'contains(trading)': False,
#   'contains(html)': False,
#   'contains(lloyd)': False,
#   'contains(rate)': False,
#   'contains(index)': False,
#   'contains(transaction)': False,
#   'contains(support)': False,
#   'contains(revised)': False,
#   'contains(own)': False,
#   'contains(adobe)': False,
#   'contains(entex)': False,
#   'contains(additional)': False,
#   'contains(security)': False,
#   'contains(copy)': False,
#   'contains(prescription)': False,
#   'contains(ces)': False,
#   'contains(global)': True,
#   'contains(once)': False,
#   'contains(issues)': False,
#   'contains(performance)': False,
#   'contains(paliourg)': False,
#   'contains(increase)': False,
#   'contains(currently)': False,
#   'contains(32)': False,
#   'contains(fred)': False,
#   'contains(camp)': False,
#   'contains(hi)': False,
#   'contains(offers)': False,
#   'contains(remove)': False,
#   'contains(long)': False,
#   'contains(pops)': False,
#   'contains(think)': False,
#   'contains(going)': False,
#   'contains(further)': False,
#   'contains(numbers)': False,
#   'contains(agreement)': False,
#   'contains(via)': False,
#   'contains(herod)': False,
#   'contains(hours)': False,
#   'contains(come)': False,
#   'contains(until)': False,
#   'contains(every)': False,
#   'contains(500)': False,
#   'contains(access)': False,
#   'contains(fyi)': False,
#   'contains(bob)': False,
#   'contains(bgcolor)': False,
#   'contains(luong)': False,
#   'contains(used)': False,
#   'contains(sell)': False,
#   'contains(put)': False,
#   'contains(months)': False,
#   'contains(someone)': False,
#   'contains(control)': False,
#   'contains(while)': False,
#   'contains(using)': False,
#   'contains(position)': False,
#   'contains(review)': False,
#   'contains(prior)': False,
#   'contains(dollars)': False,
#   'contains(stella)': False,
#   'contains(working)': False,
#   'contains(done)': False,
#   'contains(clynes)': False,
#   'contains(possible)': False,
#   'contains(midcon)': False,
#   'contains(part)': False,
#   'contains(eastrans)': False,
#   'contains(cd)': False,
#   'contains(believe)': False,
#   'contains(soon)': False,
#   'contains(notice)': False,
#   'contains(contracts)': False,
#   'contains(start)': False,
#   'contains(results)': False,
#   'contains(limited)': False,
#   'contains(act)': False,
#   'contains(details)': False,
#   'contains(counterparty)': False,
#   'contains(received)': False,
#   'contains(michael)': False,
#   'contains(cialis)': False,
#   'contains(allen)': False,
#   'contains(pay)': False,
#   'contains(accounting)': False,
#   'contains(35)': False,
#   'contains(content)': False,
#   'contains(health)': False,
#   'contains(biz)': False,
#   'contains(95)': False,
#   'contains(works)': False,
#   'contains(pro)': False,
#   'contains(charlotte)': False,
#   'contains(web)': False,
#   'contains(meyers)': False,
#   'contains(weight)': False,
#   'contains(required)': False,
#   'contains(mg)': False,
#   'contains(brian)': False,
#   'contains(project)': False,
#   'contains(duke)': False,
#   'contains(retail)': False,
#   'contains(cash)': False,
#   'contains(newsletter)': False,
#   'contains(got)': False,
#   'contains(even)': False,
#   'contains(life)': False,
#   'contains(stacey)': False,
#   'contains(storage)': False,
#   'contains(strong)': False,
#   'contains(jpg)': False,
#   'contains(124)': False,
#   'contains(natural)': False,
#   'contains(monday)': False,
#   'contains(reports)': False,
#   'contains(scott)': False,
#   'contains(customer)': False,
#   'contains(correct)': False,
#   'contains(current)': False,
#   'contains(survey)': False,
#   'contains(ranch)': False,
#   'contains(manager)': False,
#   'contains(loss)': False,
#   'contains(real)': False,
#   'contains(dec)': False,
#   'contains(power)': False,
#   'contains(fax)': False,
#   'contains(section)': False,
#   'contains(during)': False,
#   'contains(allocated)': False,
#   'contains(resources)': False,
#   'contains(easy)': False,
#   'contains(y)': False,
#   'contains(east)': False,
#   'contains(including)': False,
#   'contains(interest)': False,
#   'contains(type)': False,
#   'contains(phone)': False,
#   'contains(thu)': False,
#   'contains(de)': False,
#   'contains(feel)': False,
#   'contains(private)': False,
#   'contains(stocks)': False,
#   'contains(vance)': False,
#   'contains(why)': False,
#   'contains(carthage)': False,
#   'contains(hsc)': False,
#   'contains(follow)': False,
#   'contains(advice)': False,
#   'contains(top)': False,
#   'contains(commercial)': False,
#   'contains(gif)': False,
#   'contains(000000)': False,
#   'contains(way)': False,
#   'contains(july)': False,
#   'contains(never)': False,
#   'contains(able)': False,
#   'contains(scheduled)': False,
#   'contains(moopid)': False,
#   'contains(hotlist)': False,
#   'contains(complete)': False,
#   'contains(drugs)': False,
#   'contains(getting)': False,
#   'contains(city)': False,
#   'contains(lannou)': False,
#   'contains(corporation)': False,
#   'contains(cost)': False,
#   'contains(read)': False,
#   'contains(pain)': False,
#   'contains(div)': False,
#   'contains(oil)': False,
#   'contains(however)': False,
#   'contains(program)': False,
#   'contains(removed)': False,
#   'contains(page)': False,
#   'contains(move)': False,
#   'contains(include)': False,
#   'contains(houston)': False,
#   'contains(man)': False,
#   'contains(costs)': False,
#   'contains(old)': False,
#   'contains(tuesday)': False,
#   'contains(receipt)': False,
#   'contains(said)': False,
#   'contains(rc)': False,
#   'contains(release)': False,
#   'contains(body)': False,
#   'contains(table)': False,
#   'contains(valid)': False,
#   'contains(too)': False,
#   'contains(david)': False,
#   'contains(provided)': False,
#   'contains(taylor)': False,
#   'contains(country)': False,
#   'contains(error)': False,
#   'contains(try)': False,
#   'contains(xanax)': False,
#   'contains(form)': False,
#   'contains(open)': False,
#   'contains(mar)': False,
#   'contains(necessary)': False,
#   'contains(co)': False,
#   'contains(htmlimg)': False,
#   'contains(another)': False,
#   'contains(anything)': False,
#   'contains(better)': False,
#   'contains(suite)': False,
#   'contains(shipping)': False,
#   'contains(continue)': False,
#   'contains(past)': False,
#   'contains(calls)': False,
#   'contains(\\)': False,
#   'contains(buyback)': False,
#   'contains(clear)': False,
#   'contains(party)': False,
#   'contains(third)': False,
#   'contains(regarding)': False,
#   'contains(update)': False,
#   'contains(images)': False,
#   'contains(book)': False,
#   'contains(yet)': False,
#   'contains(zero)': False,
#   'contains(bryan)': False,
#   'contains(original)': False,
#   'contains(200)': False,
#   'contains(cotton)': False,
#   'contains(55)': False,
#   'contains(ever)': False,
#   'contains(systems)': False,
#   'contains(investing)': False,
#   'contains(36)': False,
#   'contains(source)': False,
#   'contains(add)': False,
#   'contains(morning)': False,
#   'contains(flowed)': False,
#   'contains(melissa)': False,
#   'contains(fuels)': False,
#   'contains(path)': False,
#   'contains(spam)': False,
#   'contains(between)': False,
#   'contains(always)': False,
#   'contains(mark)': False,
#   'contains(regards)': False,
#   'contains(super)': False,
#   'contains(valium)': False,
#   'contains(united)': False,
#   'contains(ken)': False,
#   'contains(everyone)': False,
#   'contains(215)': False,
#   'contains(lst)': False,
#   'contains(everything)': False,
#   'contains(application)': False,
#   'contains(800)': False,
#   'contains(few)': False,
#   'contains(300)': False,
#   'contains(something)': False,
#   'contains(love)': False,
#   'contains(70)': False,
#   'contains(found)': False,
#   'contains(case)': False,
#   'contains(term)': False,
#   'contains(ensure)': False,
#   'contains(charge)': False,
#   'contains(fill)': False,
#   'contains(three)': False,
#   'contains(shares)': False,
#   'contains(img)': False,
#   'contains(jennifer)': False,
#   'contains(box)': False,
#   'contains(either)': False,
#   'contains(left)': False,
#   'contains(valley)': False,
#   'contains(cause)': False,
#   'contains(transfer)': False,
#   'contains(cheap)': False,
#   'contains(zone)': False,
#   'contains(estimates)': False,
#   'contains(sally)': False,
#   'contains(department)': False,
#   'contains(php)': False,
#   'contains(server)': False,
#   'contains(south)': False,
#   'contains(technology)': False,
#   'contains(aol)': False,
#   'contains(encina)': False,
#   'contains(weekend)': False,
#   'contains(acton)': False,
#   'contains(close)': False,
#   'contains(little)': False,
#   'contains(yourself)': False,
#   'contains(duty)': False,
#   'contains(already)': False,
#   'contains(75)': False,
#   'contains(cs)': False,
#   'contains(wish)': False,
#   'contains(public)': False,
#   'contains(mobile)': False,
#   'contains(late)': False,
#   'contains(hanks)': False,
#   'contains(communications)': False,
#   'contains(music)': False,
#   'contains(equistar)': False,
#   'contains(john)': False,
#   'contains(created)': False,
#   'contains(industry)': False,
#   'contains(sherlyn)': False,
#   'contains(different)': False,
#   'contains(fact)': False,
#   'contains(trade)': False,
#   'contains(~)': False,
#   'contains(direct)': False,
#   'contains(drive)': False,
#   'contains(years)': False,
#   'contains(quick)': False,
#   'contains(pricing)': False,
#   'contains(browser)': False,
#   'contains(second)': False,
#   'contains(customers)': False,
#   'contains(photoshop)': False,
#   'contains(head)': False,
#   'contains(field)': False,
#   'contains(text)': False,
#   'contains(thomas)': False,
#   'contains(ms)': False,
#   'contains(side)': False,
#   'contains(longer)': False,
#   'contains(around)': False,
#   'contains(worldwide)': False,
#   'contains(anyone)': False,
#   'contains(37)': False,
#   'contains(credit)': False,
#   'contains(lose)': False,
#   'contains(states)': False,
#   'contains(generic)': False,
#   'contains(morris)': False,
#   'contains(gco)': False,
#   'contains(reliantenergy)': False,
#   'contains(remember)': False,
#   'contains(56)': False,
#   'contains(canada)': False,
#   'contains(really)': False,
#   'contains(view)': False,
#   'contains(play)': False,
#   'contains(registered)': False,
#   'contains(devon)': False,
#   'contains(problems)': False,
#   'contains(publisher)': False,
#   'contains(him)': False,
#   'contains(wanted)': False,
#   'contains(else)': False,
#   'contains(december)': False,
#   'contains(etc)': False,
#   'contains(012)': False,
#   'contains(sold)': False,
#   'contains(paste)': False,
#   'contains(hey)': False,
#   'contains(methanol)': False,
#   'contains(major)': False,
#   'contains(soft)': False,
#   'contains(men)': False,
#   'contains(fuel)': False,
#   'contains(gcs)': False,
#   'contains(cec)': False,
#   'contains(unsubscribe)': False,
#   'contains(james)': False,
#   'contains(ees)': False,
#   'contains(schedule)': False,
#   'contains(lauri)': False,
#   'contains(boas)': False,
#   'contains(gomes)': False,
#   'contains(plan)': False,
#   'contains(logistics)': False,
#   'contains(33)': False,
#   'contains(reason)': False,
#   'contains(press)': False,
#   'contains(actual)': False,
#   'contains(52)': False,
#   'contains(person)': False,
#   'contains(withers)': False,
#   'contains(fund)': False,
#   'contains(family)': False,
#   'contains(cf)': False,
#   'contains(dear)': False,
#   'contains(thursday)': False,
#   'contains(secure)': False,
#   'contains(key)': False,
#   'contains(training)': False,
#   'contains(features)': False,
#   'contains(hawkins)': False,
#   'contains(growth)': False,
#   'contains(beaumont)': False,
#   'contains(compliance)': False,
#   'contains(reveffo)': False,
#   'contains(graves)': False,
#   'contains(plus)': False,
#   'contains(version)': False,
#   'contains(small)': False,
#   'contains(swing)': False,
#   'contains(bank)': False,
#   'contains(hard)': False,
#   'contains(medications)': False,
#   'contains(kind)': False,
#   'contains(area)': False,
#   'contains(allow)': False,
#   'contains(solution)': False,
#   'contains(})': False,
#   'contains(level)': False,
#   'contains(material)': False,
#   'contains(34)': False,
#   'contains(user)': False,
#   'contains(allocation)': False,
#   'contains(im)': False,
#   'contains(personal)': False,
#   'contains(teco)': False,
#   'contains(president)': False,
#   'contains(ali)': False,
#   'contains(darial)': False,
#   'contains(lee)': True,
#   'contains(kenneth)': False,
#   'contains(rita)': False,
#   'contains(valero)': False,
#   'contains(learn)': False,
#   'contains(carlos)': False,
#   'contains(spot)': False,
#   'contains(rd)': False,
#   'contains(mid)': False,
#   'contains(48)': False,
#   'contains(meet)': False,
#   'contains(legal)': False,
#   'contains(bill)': False,
#   'contains(approximately)': False,
#   'contains(download)': False,
#   'contains(gr)': False,
#   'contains(trevino)': False,
#   'contains(fw)': False,
#   'contains(shut)': False,
#   'contains(·)': False,
#   'contains(0310041)': False,
#   'contains(king)': False,
#   'contains(aware)': False,
#   'contains(cut)': False,
#   'contains(amount)': False,
#   'contains(sex)': False,
#   'contains(experience)': False,
#   'contains(doctor)': False,
#   'contains(nominations)': False,
#   'contains(making)': False,
#   'contains(panenergy)': False,
#   'contains(hope)': False,
#   'contains(called)': False,
#   'contains(thing)': False,
#   'contains(therefore)': False,
#   'contains(tell)': False,
#   'contains(mr)': False,
#   'contains(network)': False,
#   'contains(updated)': False,
#   'contains(might)': False,
#   'contains(imbalance)': False,
#   'contains(supply)': False,
#   'contains(property)': False,
#   'contains(prize)': False,
#   'contains(cds)': False,
#   'contains(wellhead)': False,
#   'contains(things)': False,
#   'contains(58)': False,
#   'contains(42)': False,
#   'contains(paid)': False,
#   'contains(addition)': False,
#   'contains(begin)': False,
#   'contains(39)': False,
#   'contains(events)': False,
#   'contains(weeks)': False,
#   'contains(latest)': False,
#   'contains(several)': False,
#   'contains(interested)': False,
#   'contains(49)': False,
#   'contains(shows)': False,
#   'contains(tina)': False,
#   'contains(safe)': False,
#   'contains(related)': False,
#   'contains(directly)': False,
#   'contains(hello)': False,
#   'contains(yvette)': False,
#   'contains(china)': False,
#   'contains(federal)': False,
#   'contains(whole)': False,
#   'contains(expected)': False,
#   'contains(options)': False,
#   'contains(pc)': False,
#   'contains(iit)': False,
#   'contains(demokritos)': False,
#   'contains(approved)': False,
#   'contains(dave)': False,
#   'contains(gold)': False,
#   'contains(title)': False,
#   'contains(neuweiler)': False,
#   'contains(971)': False,
#   'contains(mx)': False,
#   'contains(0424040)': False,
#   'contains(ftar)': False,
#   'contains(given)': False,
#   'contains(feedback)': False,
#   'contains(research)': False,
#   'contains(38)': False,
#   'contains(bridge)': False,
#   'contains(fast)': False,
#   'contains(create)': False,
#   'contains(confirm)': False,
#   'contains(understand)': False,
#   'contains(thru)': False,
#   'contains(thought)': False,
#   'contains(lp)': False,
#   'contains(status)': False,
#   'contains(letter)': False,
#   'contains(doing)': False,
#   'contains(having)': False,
#   'contains(monthly)': False,
#   'contains(large)': False,
#   'contains(away)': False,
#   'contains(kimberly)': False,
#   'contains(q)': False,
#   'contains(follows)': False,
#   'contains(yahoo)': False,
#   'contains({)': False,
#   'contains(takes)': False,
#   'contains(exchange)': False,
#   ...},
#  'ham')

# %%
#Naive Bayes classifier with 5-fold cross validation for training on sentiments using
#expanded unigram features vocabulary

start = time.time()
kf = KFold(n_splits = num_split)
sum = 0
prec = 0
recall = 0

for train, test in kf.split(featuresets4):
    train_data = np.array(featuresets4)[train]
    test_data = np.array(featuresets4)[test]
    classifier = nltk.NaiveBayesClassifier.train(train_data)
    sum += nltk.classify.accuracy(classifier, test_data)
    
    #calculating precision and recall 
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)

    for i, (feats, label) in enumerate(test_data):
        refsets[label].add(i)
        observed = classifier.classify(feats)
        testsets[observed].add(i)
    
    prec += nltk.precision(refsets['spam'], testsets['spam'])
    recall += nltk.recall(refsets['spam'], testsets['spam'])

#storing the score in a variable 
acc4 = sum/num_split
avg_precision4 = prec/num_split
avg_recall4 = recall/num_split

end = time.time()
print("Processing Time: {0:.2f} seconds".format(end - start))

#let's see the accuracy score for this new classifier
print("Accuracy:", round(acc4,4))
print("Precision:", round(avg_precision4,4))
print("Recall:", round(avg_recall4,4))
# Out:
# Processing Time: 76.23 seconds
# Accuracy: 0.9625
# Precision: 0.9309
# Recall: 1.0

# %%
## BONUS EXPERIMENT - COMBINE THE STOPWORD REMOVAL WITH INCREASED VOCABULARY ##

top_words = nltk.FreqDist(all_words_stopped)
most_common_words = top_words.most_common(5000)
word_features5 = [word for (word,count) in most_common_words]
word_features5[:20]
# Out:
# ['ect',
#  'hou',
#  'Subject',
#  '!',
#  '2000',
#  'enron',
#  '3',
#  '$',
#  'please',
#  '``',
#  '1',
#  'com',
#  '2',
#  'e',
#  '%',
#  '00',
#  '#',
#  '>',
#  'subject',
#  'meter']

# %%
#now we apply the function to the document dataset
featuresets5 = [(document_features(d, word_features5), c) for (d, c) in emaildocs]

#we print the list of features matches for the first document ([0]) in the corpus
featuresets5[0]
# Out:
# ({'contains(ect)': False,
#   'contains(hou)': False,
#   'contains(Subject)': True,
#   'contains(!)': False,
#   'contains(2000)': False,
#   'contains(enron)': False,
#   'contains(3)': False,
#   'contains($)': False,
#   'contains(please)': False,
#   'contains(``)': False,
#   'contains(1)': False,
#   'contains(com)': False,
#   'contains(2)': False,
#   'contains(e)': False,
#   'contains(%)': False,
#   'contains(00)': False,
#   'contains(#)': True,
#   'contains(>)': False,
#   'contains(subject)': False,
#   'contains(meter)': False,
#   'contains(pm)': False,
#   'contains(gas)': True,
#   'contains(cc)': False,
#   'contains(deal)': False,
#   'contains(0)': True,
#   'contains(http)': False,
#   'contains(99)': False,
#   'contains(000)': False,
#   'contains(corp)': False,
#   'contains(new)': False,
#   'contains(thanks)': False,
#   'contains(get)': False,
#   'contains(10)': False,
#   'contains(4)': False,
#   'contains(5)': False,
#   'contains(&)': False,
#   'contains(know)': False,
#   'contains(|)': False,
#   'contains(need)': False,
#   'contains(forwarded)': False,
#   'contains(03)': False,
#   'contains(12)': False,
#   'contains(p)': False,
#   'contains(may)': False,
#   'contains(daren)': False,
#   'contains(hpl)': False,
#   'contains(7)': False,
#   'contains(information)': False,
#   'contains(us)': False,
#   'contains(company)': False,
#   'contains(01)': False,
#   'contains(mmbtu)': False,
#   'contains(05)': False,
#   'contains(www)': False,
#   'contains(04)': False,
#   'contains(02)': False,
#   'contains(l)': False,
#   'contains(let)': False,
#   'contains(time)': False,
#   'contains(would)': False,
#   'contains(6)': False,
#   'contains(11)': False,
#   'contains(price)': False,
#   'contains(b)': False,
#   'contains(one)': True,
#   'contains(th)': False,
#   'contains(month)': False,
#   'contains(mail)': False,
#   'contains(contract)': False,
#   'contains(8)': False,
#   'contains(td)': False,
#   'contains(email)': False,
#   'contains(nbsp)': False,
#   'contains(sitara)': True,
#   'contains(see)': False,
#   'contains(20)': False,
#   'contains(j)': False,
#   'contains(])': False,
#   'contains([)': False,
#   'contains(day)': False,
#   'contains(x)': False,
#   'contains(also)': False,
#   'contains(15)': False,
#   'contains(volume)': False,
#   'contains(free)': False,
#   'contains(like)': False,
#   'contains(energy)': False,
#   'contains(c)': False,
#   'contains(deals)': False,
#   'contains(font)': False,
#   'contains(pills)': False,
#   'contains(change)': False,
#   'contains(ami)': False,
#   'contains(30)': False,
#   'contains(business)': False,
#   'contains(message)': False,
#   'contains(want)': False,
#   'contains(r)': False,
#   'contains(volumes)': False,
#   'contains(2004)': False,
#   'contains(attached)': False,
#   'contains(+)': False,
#   'contains(farmer)': False,
#   'contains(xls)': False,
#   'contains(09)': False,
#   'contains(questions)': False,
#   'contains(contact)': False,
#   'contains(9)': False,
#   'contains(make)': False,
#   'contains(width)': False,
#   'contains(report)': False,
#   'contains(25)': False,
#   'contains(60)': False,
#   'contains(call)': False,
#   'contains(06)': False,
#   'contains(list)': False,
#   'contains(click)': False,
#   'contains(back)': False,
#   'contains(money)': False,
#   'contains(f)': False,
#   'contains(100)': False,
#   'contains(texas)': False,
#   'contains(could)': False,
#   'contains(nom)': False,
#   'contains(set)': False,
#   'contains(chokshi)': False,
#   'contains(inc)': False,
#   'contains(robert)': False,
#   'contains(height)': False,
#   'contains(following)': False,
#   'contains(order)': False,
#   'contains(24)': False,
#   'contains(50)': False,
#   'contains(forward)': False,
#   'contains(production)': False,
#   'contains(08)': False,
#   'contains(w)': False,
#   'contains(january)': False,
#   'contains(21)': False,
#   'contains(per)': False,
#   'contains(today)': False,
#   'contains(statements)': False,
#   'contains(march)': False,
#   'contains(best)': False,
#   'contains(sale)': False,
#   'contains(ena)': False,
#   'contains(number)': False,
#   'contains(k)': False,
#   'contains(available)': False,
#   'contains(first)': False,
#   'contains(g)': False,
#   'contains(take)': True,
#   'contains(31)': False,
#   'contains(system)': False,
#   'contains(align)': False,
#   'contains(sent)': False,
#   'contains(go)': False,
#   'contains(days)': False,
#   'contains(help)': False,
#   'contains(management)': False,
#   'contains(98)': False,
#   'contains(stock)': False,
#   'contains(jackie)': False,
#   'contains(u)': False,
#   'contains(v)': False,
#   'contains(tr)': False,
#   'contains(online)': False,
#   'contains(23)': False,
#   'contains(ticket)': True,
#   'contains(changes)': False,
#   'contains(june)': False,
#   'contains(size)': False,
#   'contains(within)': False,
#   'contains(n)': False,
#   'contains(14)': False,
#   'contains(flow)': False,
#   'contains(border)': False,
#   'contains(info)': False,
#   'contains(last)': False,
#   'contains(18)': False,
#   'contains(nd)': False,
#   'contains(well)': False,
#   'contains(group)': False,
#   'contains(16)': False,
#   'contains(gary)': False,
#   'contains(address)': False,
#   'contains(service)': False,
#   'contains(next)': False,
#   'contains(team)': False,
#   'contains(transport)': False,
#   'contains(pec)': False,
#   'contains(effective)': False,
#   'contains(work)': False,
#   'contains(color)': False,
#   'contains(april)': False,
#   'contains(due)': False,
#   'contains(face)': False,
#   'contains(use)': False,
#   'contains(account)': False,
#   'contains(buy)': False,
#   'contains(sales)': False,
#   'contains(looking)': False,
#   'contains(69)': False,
#   'contains(22)': False,
#   'contains(nomination)': False,
#   'contains(many)': False,
#   'contains(office)': False,
#   'contains(without)': False,
#   'contains(offer)': False,
#   'contains(microsoft)': False,
#   "contains('')": False,
#   'contains(net)': False,
#   'contains(services)': False,
#   'contains(week)': False,
#   'contains(prices)': False,
#   'contains(name)': False,
#   'contains(63)': False,
#   'contains(year)': False,
#   'contains(19)': False,
#   'contains(feb)': False,
#   'contains(save)': False,
#   'contains(delivery)': False,
#   'contains(17)': False,
#   'contains(line)': False,
#   'contains(thank)': False,
#   'contains(link)': False,
#   'contains(send)': False,
#   'contains(aimee)': False,
#   'contains(special)': False,
#   'contains(13)': False,
#   'contains(date)': False,
#   'contains(desk)': False,
#   'contains(million)': False,
#   'contains(27)': False,
#   'contains(file)': False,
#   'contains(40)': False,
#   'contains(investment)': False,
#   'contains(href)': False,
#   'contains(src)': False,
#   'contains(products)': False,
#   'contains(90)': False,
#   'contains(made)': False,
#   'contains(br)': False,
#   'contains(pat)': False,
#   'contains(future)': False,
#   'contains(needs)': True,
#   'contains(software)': False,
#   'contains(161)': False,
#   'contains(two)': False,
#   'contains(give)': False,
#   'contains(steve)': False,
#   'contains(windows)': False,
#   'contains(meeting)': False,
#   'contains(process)': False,
#   'contains(120)': False,
#   'contains(based)': False,
#   'contains(h)': False,
#   'contains(place)': False,
#   'contains(stop)': False,
#   'contains(jan)': False,
#   'contains(marketing)': False,
#   'contains(viagra)': False,
#   'contains(data)': False,
#   'contains(george)': False,
#   'contains(good)': False,
#   'contains(computron)': False,
#   'contains(check)': False,
#   'contains(tom)': False,
#   'contains(internet)': False,
#   'contains(people)': False,
#   'contains(look)': False,
#   'contains(securities)': False,
#   'contains(professional)': False,
#   'contains(hplc)': False,
#   'contains(28)': False,
#   'contains(anita)': False,
#   'contains(29)': False,
#   'contains(julie)': False,
#   'contains(america)': False,
#   'contains(site)': False,
#   'contains(find)': False,
#   'contains(receive)': False,
#   'contains(risk)': True,
#   'contains(reply)': False,
#   'contains(mary)': False,
#   'contains(45)': False,
#   'contains(pg)': False,
#   'contains(international)': False,
#   'contains(market)': False,
#   'contains(february)': False,
#   'contains(world)': False,
#   'contains(susan)': False,
#   'contains(tickets)': False,
#   'contains(since)': False,
#   'contains(meters)': False,
#   'contains(much)': False,
#   'contains(purchase)': False,
#   'contains(sure)': False,
#   'contains(young)': False,
#   'contains(howard)': False,
#   'contains(provide)': False,
#   'contains(home)': False,
#   'contains(rates)': False,
#   'contains(44)': False,
#   'contains(07)': False,
#   'contains(unify)': False,
#   'contains(high)': False,
#   'contains(26)': False,
#   'contains(pipeline)': False,
#   'contains(\x01)': False,
#   'contains(development)': False,
#   'contains(brenda)': False,
#   'contains(xp)': False,
#   'contains(smith)': False,
#   'contains(visit)': False,
#   'contains(center)': False,
#   'contains(north)': False,
#   'contains(right)': False,
#   'contains(st)': False,
#   'contains(request)': False,
#   'contains(problem)': False,
#   'contains(great)': False,
#   'contains(total)': False,
#   'contains(activity)': False,
#   'contains(financial)': False,
#   'contains(point)': False,
#   'contains(needed)': False,
#   'contains(`)': False,
#   'contains(operations)': False,
#   'contains(2003)': False,
#   'contains(companies)': False,
#   'contains(product)': False,
#   'contains(friday)': False,
#   'contains(meds)': False,
#   'contains(end)': False,
#   'contains(still)': False,
#   'contains(id)': False,
#   'contains(80)': False,
#   'contains(less)': False,
#   'contains(issue)': False,
#   'contains(1999)': False,
#   'contains(lisa)': False,
#   'contains(daily)': True,
#   'contains(show)': False,
#   'contains(low)': False,
#   'contains(stephanie)': False,
#   'contains(713)': False,
#   'contains(plant)': False,
#   'contains(note)': False,
#   'contains(noms)': False,
#   'contains(must)': False,
#   'contains(news)': False,
#   'contains(keep)': False,
#   'contains(full)': False,
#   'contains(quality)': False,
#   'contains(trading)': False,
#   'contains(html)': False,
#   'contains(lloyd)': False,
#   'contains(rate)': False,
#   'contains(index)': False,
#   'contains(transaction)': False,
#   'contains(support)': False,
#   'contains(revised)': False,
#   'contains(adobe)': False,
#   'contains(entex)': False,
#   'contains(additional)': False,
#   'contains(security)': False,
#   'contains(copy)': False,
#   'contains(prescription)': False,
#   'contains(ces)': False,
#   'contains(global)': True,
#   'contains(issues)': False,
#   'contains(performance)': False,
#   'contains(paliourg)': False,
#   'contains(increase)': False,
#   'contains(currently)': False,
#   'contains(32)': False,
#   'contains(fred)': False,
#   'contains(camp)': False,
#   'contains(hi)': False,
#   'contains(offers)': False,
#   'contains(remove)': False,
#   'contains(long)': False,
#   'contains(pops)': False,
#   'contains(think)': False,
#   'contains(going)': False,
#   'contains(numbers)': False,
#   'contains(agreement)': False,
#   'contains(via)': False,
#   'contains(herod)': False,
#   'contains(hours)': False,
#   'contains(come)': False,
#   'contains(every)': False,
#   'contains(500)': False,
#   'contains(access)': False,
#   'contains(fyi)': False,
#   'contains(bob)': False,
#   'contains(bgcolor)': False,
#   'contains(luong)': False,
#   'contains(used)': False,
#   'contains(sell)': False,
#   'contains(put)': False,
#   'contains(months)': False,
#   'contains(someone)': False,
#   'contains(control)': False,
#   'contains(using)': False,
#   'contains(position)': False,
#   'contains(review)': False,
#   'contains(prior)': False,
#   'contains(dollars)': False,
#   'contains(stella)': False,
#   'contains(working)': False,
#   'contains(done)': False,
#   'contains(clynes)': False,
#   'contains(possible)': False,
#   'contains(midcon)': False,
#   'contains(part)': False,
#   'contains(eastrans)': False,
#   'contains(cd)': False,
#   'contains(believe)': False,
#   'contains(soon)': False,
#   'contains(notice)': False,
#   'contains(contracts)': False,
#   'contains(start)': False,
#   'contains(results)': False,
#   'contains(limited)': False,
#   'contains(act)': False,
#   'contains(details)': False,
#   'contains(counterparty)': False,
#   'contains(received)': False,
#   'contains(michael)': False,
#   'contains(cialis)': False,
#   'contains(allen)': False,
#   'contains(pay)': False,
#   'contains(accounting)': False,
#   'contains(35)': False,
#   'contains(content)': False,
#   'contains(health)': False,
#   'contains(biz)': False,
#   'contains(95)': False,
#   'contains(works)': False,
#   'contains(pro)': False,
#   'contains(charlotte)': False,
#   'contains(web)': False,
#   'contains(meyers)': False,
#   'contains(weight)': False,
#   'contains(required)': False,
#   'contains(mg)': False,
#   'contains(brian)': False,
#   'contains(project)': False,
#   'contains(duke)': False,
#   'contains(retail)': False,
#   'contains(cash)': False,
#   'contains(newsletter)': False,
#   'contains(got)': False,
#   'contains(even)': False,
#   'contains(life)': False,
#   'contains(stacey)': False,
#   'contains(storage)': False,
#   'contains(strong)': False,
#   'contains(jpg)': False,
#   'contains(124)': False,
#   'contains(natural)': False,
#   'contains(monday)': False,
#   'contains(reports)': False,
#   'contains(scott)': False,
#   'contains(customer)': False,
#   'contains(correct)': False,
#   'contains(current)': False,
#   'contains(survey)': False,
#   'contains(ranch)': False,
#   'contains(manager)': False,
#   'contains(loss)': False,
#   'contains(real)': False,
#   'contains(dec)': False,
#   'contains(power)': False,
#   'contains(fax)': False,
#   'contains(section)': False,
#   'contains(allocated)': False,
#   'contains(resources)': False,
#   'contains(easy)': False,
#   'contains(east)': False,
#   'contains(including)': False,
#   'contains(interest)': False,
#   'contains(type)': False,
#   'contains(phone)': False,
#   'contains(thu)': False,
#   'contains(de)': False,
#   'contains(feel)': False,
#   'contains(private)': False,
#   'contains(stocks)': False,
#   'contains(vance)': False,
#   'contains(carthage)': False,
#   'contains(hsc)': False,
#   'contains(follow)': False,
#   'contains(advice)': False,
#   'contains(top)': False,
#   'contains(commercial)': False,
#   'contains(gif)': False,
#   'contains(000000)': False,
#   'contains(way)': False,
#   'contains(july)': False,
#   'contains(never)': False,
#   'contains(able)': False,
#   'contains(scheduled)': False,
#   'contains(moopid)': False,
#   'contains(hotlist)': False,
#   'contains(complete)': False,
#   'contains(drugs)': False,
#   'contains(getting)': False,
#   'contains(city)': False,
#   'contains(lannou)': False,
#   'contains(corporation)': False,
#   'contains(cost)': False,
#   'contains(read)': False,
#   'contains(pain)': False,
#   'contains(div)': False,
#   'contains(oil)': False,
#   'contains(however)': False,
#   'contains(program)': False,
#   'contains(removed)': False,
#   'contains(page)': False,
#   'contains(move)': False,
#   'contains(include)': False,
#   'contains(houston)': False,
#   'contains(man)': False,
#   'contains(costs)': False,
#   'contains(old)': False,
#   'contains(tuesday)': False,
#   'contains(receipt)': False,
#   'contains(said)': False,
#   'contains(rc)': False,
#   'contains(release)': False,
#   'contains(body)': False,
#   'contains(table)': False,
#   'contains(valid)': False,
#   'contains(david)': False,
#   'contains(provided)': False,
#   'contains(taylor)': False,
#   'contains(country)': False,
#   'contains(error)': False,
#   'contains(try)': False,
#   'contains(xanax)': False,
#   'contains(form)': False,
#   'contains(open)': False,
#   'contains(mar)': False,
#   'contains(necessary)': False,
#   'contains(co)': False,
#   'contains(htmlimg)': False,
#   'contains(another)': False,
#   'contains(anything)': False,
#   'contains(better)': False,
#   'contains(suite)': False,
#   'contains(shipping)': False,
#   'contains(continue)': False,
#   'contains(past)': False,
#   'contains(calls)': False,
#   'contains(\\)': False,
#   'contains(buyback)': False,
#   'contains(clear)': False,
#   'contains(party)': False,
#   'contains(third)': False,
#   'contains(regarding)': False,
#   'contains(update)': False,
#   'contains(images)': False,
#   'contains(book)': False,
#   'contains(yet)': False,
#   'contains(zero)': False,
#   'contains(bryan)': False,
#   'contains(original)': False,
#   'contains(200)': False,
#   'contains(cotton)': False,
#   'contains(55)': False,
#   'contains(ever)': False,
#   'contains(systems)': False,
#   'contains(investing)': False,
#   'contains(36)': False,
#   'contains(source)': False,
#   'contains(add)': False,
#   'contains(morning)': False,
#   'contains(flowed)': False,
#   'contains(melissa)': False,
#   'contains(fuels)': False,
#   'contains(path)': False,
#   'contains(spam)': False,
#   'contains(always)': False,
#   'contains(mark)': False,
#   'contains(regards)': False,
#   'contains(super)': False,
#   'contains(valium)': False,
#   'contains(united)': False,
#   'contains(ken)': False,
#   'contains(everyone)': False,
#   'contains(215)': False,
#   'contains(lst)': False,
#   'contains(everything)': False,
#   'contains(application)': False,
#   'contains(800)': False,
#   'contains(300)': False,
#   'contains(something)': False,
#   'contains(love)': False,
#   'contains(70)': False,
#   'contains(found)': False,
#   'contains(case)': False,
#   'contains(term)': False,
#   'contains(ensure)': False,
#   'contains(charge)': False,
#   'contains(fill)': False,
#   'contains(three)': False,
#   'contains(shares)': False,
#   'contains(img)': False,
#   'contains(jennifer)': False,
#   'contains(box)': False,
#   'contains(either)': False,
#   'contains(left)': False,
#   'contains(valley)': False,
#   'contains(cause)': False,
#   'contains(transfer)': False,
#   'contains(cheap)': False,
#   'contains(zone)': False,
#   'contains(estimates)': False,
#   'contains(sally)': False,
#   'contains(department)': False,
#   'contains(php)': False,
#   'contains(server)': False,
#   'contains(south)': False,
#   'contains(technology)': False,
#   'contains(aol)': False,
#   'contains(encina)': False,
#   'contains(weekend)': False,
#   'contains(acton)': False,
#   'contains(close)': False,
#   'contains(little)': False,
#   'contains(duty)': False,
#   'contains(already)': False,
#   'contains(75)': False,
#   'contains(cs)': False,
#   'contains(wish)': False,
#   'contains(public)': False,
#   'contains(mobile)': False,
#   'contains(late)': False,
#   'contains(hanks)': False,
#   'contains(communications)': False,
#   'contains(music)': False,
#   'contains(equistar)': False,
#   'contains(john)': False,
#   'contains(created)': False,
#   'contains(industry)': False,
#   'contains(sherlyn)': False,
#   'contains(different)': False,
#   'contains(fact)': False,
#   'contains(trade)': False,
#   'contains(~)': False,
#   'contains(direct)': False,
#   'contains(drive)': False,
#   'contains(years)': False,
#   'contains(quick)': False,
#   'contains(pricing)': False,
#   'contains(browser)': False,
#   'contains(second)': False,
#   'contains(customers)': False,
#   'contains(photoshop)': False,
#   'contains(head)': False,
#   'contains(field)': False,
#   'contains(text)': False,
#   'contains(thomas)': False,
#   'contains(ms)': False,
#   'contains(side)': False,
#   'contains(longer)': False,
#   'contains(around)': False,
#   'contains(worldwide)': False,
#   'contains(anyone)': False,
#   'contains(37)': False,
#   'contains(credit)': False,
#   'contains(lose)': False,
#   'contains(states)': False,
#   'contains(generic)': False,
#   'contains(morris)': False,
#   'contains(gco)': False,
#   'contains(reliantenergy)': False,
#   'contains(remember)': False,
#   'contains(56)': False,
#   'contains(canada)': False,
#   'contains(really)': False,
#   'contains(view)': False,
#   'contains(play)': False,
#   'contains(registered)': False,
#   'contains(devon)': False,
#   'contains(problems)': False,
#   'contains(publisher)': False,
#   'contains(wanted)': False,
#   'contains(else)': False,
#   'contains(december)': False,
#   'contains(etc)': False,
#   'contains(012)': False,
#   'contains(sold)': False,
#   'contains(paste)': False,
#   'contains(hey)': False,
#   'contains(methanol)': False,
#   'contains(major)': False,
#   'contains(soft)': False,
#   'contains(men)': False,
#   'contains(fuel)': False,
#   'contains(gcs)': False,
#   'contains(cec)': False,
#   'contains(unsubscribe)': False,
#   'contains(james)': False,
#   'contains(ees)': False,
#   'contains(schedule)': False,
#   'contains(lauri)': False,
#   'contains(boas)': False,
#   'contains(gomes)': False,
#   'contains(plan)': False,
#   'contains(logistics)': False,
#   'contains(33)': False,
#   'contains(reason)': False,
#   'contains(press)': False,
#   'contains(actual)': False,
#   'contains(52)': False,
#   'contains(person)': False,
#   'contains(withers)': False,
#   'contains(fund)': False,
#   'contains(family)': False,
#   'contains(cf)': False,
#   'contains(dear)': False,
#   'contains(thursday)': False,
#   'contains(secure)': False,
#   'contains(key)': False,
#   'contains(training)': False,
#   'contains(features)': False,
#   'contains(hawkins)': False,
#   'contains(growth)': False,
#   'contains(beaumont)': False,
#   'contains(compliance)': False,
#   'contains(reveffo)': False,
#   'contains(graves)': False,
#   'contains(plus)': False,
#   'contains(version)': False,
#   'contains(small)': False,
#   'contains(swing)': False,
#   'contains(bank)': False,
#   'contains(hard)': False,
#   'contains(medications)': False,
#   'contains(kind)': False,
#   'contains(area)': False,
#   'contains(allow)': False,
#   'contains(solution)': False,
#   'contains(})': False,
#   'contains(level)': False,
#   'contains(material)': False,
#   'contains(34)': False,
#   'contains(user)': False,
#   'contains(allocation)': False,
#   'contains(im)': False,
#   'contains(personal)': False,
#   'contains(teco)': False,
#   'contains(president)': False,
#   'contains(ali)': False,
#   'contains(darial)': False,
#   'contains(lee)': True,
#   'contains(kenneth)': False,
#   'contains(rita)': False,
#   'contains(valero)': False,
#   'contains(learn)': False,
#   'contains(carlos)': False,
#   'contains(spot)': False,
#   'contains(rd)': False,
#   'contains(mid)': False,
#   'contains(48)': False,
#   'contains(meet)': False,
#   'contains(legal)': False,
#   'contains(bill)': False,
#   'contains(approximately)': False,
#   'contains(download)': False,
#   'contains(gr)': False,
#   'contains(trevino)': False,
#   'contains(fw)': False,
#   'contains(shut)': False,
#   'contains(·)': False,
#   'contains(0310041)': False,
#   'contains(king)': False,
#   'contains(aware)': False,
#   'contains(cut)': False,
#   'contains(amount)': False,
#   'contains(sex)': False,
#   'contains(experience)': False,
#   'contains(doctor)': False,
#   'contains(nominations)': False,
#   'contains(making)': False,
#   'contains(panenergy)': False,
#   'contains(hope)': False,
#   'contains(called)': False,
#   'contains(thing)': False,
#   'contains(therefore)': False,
#   'contains(tell)': False,
#   'contains(mr)': False,
#   'contains(network)': False,
#   'contains(updated)': False,
#   'contains(might)': False,
#   'contains(imbalance)': False,
#   'contains(supply)': False,
#   'contains(property)': False,
#   'contains(prize)': False,
#   'contains(cds)': False,
#   'contains(wellhead)': False,
#   'contains(things)': False,
#   'contains(58)': False,
#   'contains(42)': False,
#   'contains(paid)': False,
#   'contains(addition)': False,
#   'contains(begin)': False,
#   'contains(39)': False,
#   'contains(events)': False,
#   'contains(weeks)': False,
#   'contains(latest)': False,
#   'contains(several)': False,
#   'contains(interested)': False,
#   'contains(49)': False,
#   'contains(shows)': False,
#   'contains(tina)': False,
#   'contains(safe)': False,
#   'contains(related)': False,
#   'contains(directly)': False,
#   'contains(hello)': False,
#   'contains(yvette)': False,
#   'contains(china)': False,
#   'contains(federal)': False,
#   'contains(whole)': False,
#   'contains(expected)': False,
#   'contains(options)': False,
#   'contains(pc)': False,
#   'contains(iit)': False,
#   'contains(demokritos)': False,
#   'contains(approved)': False,
#   'contains(dave)': False,
#   'contains(gold)': False,
#   'contains(title)': False,
#   'contains(neuweiler)': False,
#   'contains(971)': False,
#   'contains(mx)': False,
#   'contains(0424040)': False,
#   'contains(ftar)': False,
#   'contains(given)': False,
#   'contains(feedback)': False,
#   'contains(research)': False,
#   'contains(38)': False,
#   'contains(bridge)': False,
#   'contains(fast)': False,
#   'contains(create)': False,
#   'contains(confirm)': False,
#   'contains(understand)': False,
#   'contains(thru)': False,
#   'contains(thought)': False,
#   'contains(lp)': False,
#   'contains(status)': False,
#   'contains(letter)': False,
#   'contains(monthly)': False,
#   'contains(large)': False,
#   'contains(away)': False,
#   'contains(kimberly)': False,
#   'contains(q)': False,
#   'contains(follows)': False,
#   'contains(yahoo)': False,
#   'contains({)': False,
#   'contains(takes)': False,
#   'contains(exchange)': False,
#   'contains(effort)': False,
#   'contains(pipe)': False,
#   'contains(starting)': False,
#   'contains(41)': False,
#   'contains(enough)': False,
#   'contains(words)': False,
#   'contains(egmnom)': False,
#   'contains(firm)': False,
#   'contains(exxon)': False,
#   'contains(changed)': True,
#   'contains(wynne)': False,
#   'contains(vicodin)': False,
#   'contains(fat)': False,
#   'contains(9497)': False,
#   'contains(computer)': False,
#   'contains(action)': False,
#   'contains(pharmacy)': False,
#   'contains(wednesday)': False,
#   'contains(operating)': False,
#   'contains(ability)': False,
#   'contains(soma)': False,
#   'contains(others)': False,
#   'contains(brand)': False,
#   'contains(dvd)': False,
#   'contains(gathering)': False,
#   'contains(understanding)': False,
#   'contains(listing)': False,
#   'contains(josey)': False,
#   'contains(receiving)': False,
#   'contains(exploration)': False,
#   'contains(wide)': False,
#   'contains(0986725)': False,
#   'contains(requested)': False,
#   'contains(valadez)': False,
#   'contains(period)': False,
#   'contains(usa)': False,
#   'contains(cover)': False,
#   'contains(assistance)': False,
#   'contains(rest)': False,
#   'contains(enter)': False,
#   'contains(requirements)': False,
#   'contains(ltd)': False,
#   'contains(advise)': False,
#   'contains(megan)': False,
#   'contains(shipped)': False,
#   'contains(say)': False,
#   'contains(expense)': False,
#   'contains(54)': False,
#   'contains(voice)': False,
#   'contains(relief)': False,
#   'contains(bruce)': False,
#   'contains(ship)': False,
#   'contains(katherine)': False,
#   'contains(57)': False,
#   'contains(run)': False,
#   'contains(times)': False,
#   'contains(revision)': False,
#   'contains(asap)': False,
#   'contains(members)': False,
#   'contains(shall)': False,
#   'contains(entered)': False,
#   'contains(offering)': False,
#   'contains(nothing)': False,
#   'contains(cheryl)': False,
#   'contains(potential)': False,
#   'contains(estimate)': False,
#   'contains(asked)': False,
#   'contains(card)': False,
#   'contains(watch)': False,
#   'contains(union)': False,
#   'contains(recent)': False,
#   'contains(distribution)': False,
#   'contains(donna)': False,
#   'contains(says)': False,
#   'contains(redeliveries)': False,
#   'contains(gra)': False,
#   'contains(ei)': False,
#   'contains(hotmail)': False,
#   'contains(tx)': False,
#   'contains(william)': False,
#   'contains(nominated)': False,
#   'contains(ua)': False,
#   'contains(oasis)': False,
#   'contains(specials)': False,
#   'contains(actuals)': False,
#   'contains(prc)': False,
#   'contains(fontfont)': False,
#   'contains(1226030)': False,
#   'contains(reflect)': False,
#   'contains(jim)': False,
#   'contains(invoices)': False,
#   'contains(response)': False,
#   'contains(rx)': False,
#   'contains(settlements)': False,
#   'contains(selected)': False,
#   'contains(items)': False,
#   'contains(air)': False,
#   'contains(overnight)': False,
#   'contains(door)': False,
#   'contains(corel)': False,
#   'contains(deliveries)': False,
#   'contains(revenue)': False,
#   'contains(website)': False,
#   'contains(usb)': False,
#   'contains(code)': False,
#   'contains(97)': False,
#   'contains(processing)': False,
#   'contains(eol)': False,
#   'contains(°)': False,
#   'contains(taken)': True,
#   'contains(troy)': False,
#   'contains(assist)': False,
#   'contains(availability)': False,
#   'contains(probably)': False,
#   'contains(listed)': False,
#   'contains(tomorrow)': False,
#   'contains(profile)': False,
#   'contains(crow)': False,
#   'contains(connor)': False,
#   'contains(track)': False,
#   'contains(taking)': False,
#   'contains(sincerely)': False,
#   'contains(cellpadding)': False,
#   'contains(passed)': False,
#   'contains(holmes)': False,
#   'contains(sorry)': False,
#   'contains(style)': False,
#   'contains(expectations)': False,
#   'contains(intended)': False,
#   'contains(nguyen)': False,
#   'contains(heidi)': False,
#   'contains(media)': False,
#   'contains(texaco)': False,
#   'contains(golf)': False,
#   ...},
#  'ham')

# %%
#Naive Bayes classifier with 5-fold cross validation for training on sentiments using
#expanded unigram features vocabulary without stopword and punctuation

start = time.time()
kf = KFold(n_splits = num_split)
sum = 0
prec = 0
recall = 0

for train, test in kf.split(featuresets5):
    train_data = np.array(featuresets5)[train]
    test_data = np.array(featuresets5)[test]
    classifier = nltk.NaiveBayesClassifier.train(train_data)
    sum += nltk.classify.accuracy(classifier, test_data)
    
    #calculating precision and recall 
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)

    for i, (feats, label) in enumerate(test_data):
        refsets[label].add(i)
        observed = classifier.classify(feats)
        testsets[observed].add(i)
    
    prec += nltk.precision(refsets['spam'], testsets['spam'])
    recall += nltk.recall(refsets['spam'], testsets['spam'])

#storing the score in a variable 
acc5 = sum/num_split
avg_precision5 = prec/num_split
avg_recall5 = recall/num_split

end = time.time()
print("Processing Time: {0:.2f} seconds".format(end - start))

#let's see the accuracy score for this new classifier
print("Accuracy:", round(acc5,4))
print("Precision:", round(avg_precision5,4))
print("Recall:", round(avg_recall5,4))
# Out:
# Processing Time: 77.58 seconds
# Accuracy: 0.976
# Precision: 0.9561
# Recall: 0.998
